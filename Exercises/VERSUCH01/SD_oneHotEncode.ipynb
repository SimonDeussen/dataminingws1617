# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random

DATA_PATH_SD = 'D:\\Data Mining\\data\\'

testdata = pd.read_csv(DATA_PATH_SD + "bigmerge.csv")
testdata = testdata.drop("Unnamed: 0", 1)
testdata = testdata.drop("gender", 1)
testdata = testdata.drop("age", 1)

# %%
def convertDFToDict(df_input):
    labels = {}
    values = {}
    for i in range(1523382):
        labels[i] = testdata['group'][i]
        values[i] = (testdata['device_id'][i], testdata['phone_brand'][i], 
                      testdata['device_model'][i], testdata['category'][i])
        
    for i in range(0,len(values)):
        values[i] = np.array(values[i])
        
    
    return labels, values

def translateBrands(data_in):
    brandMapFilePath="D:\\Data Mining\\data\\brandMap.txt"
    brandMapFile = open(brandMapFilePath, "r")
    brandMapList=[x for x in brandMapFile.read().strip().split() if x]
    brandMapList.remove(brandMapList[0]) 
    brandMap= dict()
    
    for i in range(0,len(brandMapList),2):
        brandMap.setdefault(brandMapList[i],brandMapList[i+1])
        
    for i in range(0,len(data_in)):
        brand = str(data_in[i][1])
        data_in[i][1] = brandMap[brand] if brand in brandMap else brand
    return data_in

# %%
labels, values = convertDFToDict(testdata)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-64-4e242f80da31> in <module>()
# ----> 1 labels, values = convertDFToDict(testdata)
#
# <ipython-input-63-2a5783444777> in convertDFToDict(df_input)
#       7                       testdata['device_model'][i], testdata['category'][i])
#       8
# ----> 9     for i in range(0,len(values)):
#      10         values[i] = np.array(values[i])
#      11
#
# TypeError: 'int' object is not callable

# %%
ghfg = np.array(1523382 )
for a in values:
    ghfg.append(a)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-68-8abfe275d5f7> in <module>()
#       1 ghfg = np.array(1523382 )
#       2 for a in values:
# ----> 3     ghfg.append(a)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'append'

# %%
import theano
# Out:
# WARNING (theano.configdefaults): GCC not detected ! Theano will be unable to execute optimized C-implementations (for both CPU and GPU) and will default to Python implementations. Performance will be severely degraded.
# Problem occurred during compilation with the command line below:
# g++ -shared -g -IC:\Users\simon\AppData\Local\Enthought\Canopy\User\lib\site-packages\numpy\core\include -ID:\ProgramFiles\Entought\Canopy\App\appdata\canopy-1.7.4.3348.win-x86_64\include -o C:\Users\simon\AppData\Local\Theano\compiledir_Windows-10-10.0.14393-Intel64_Family_6_Model_94_Stepping_3_GenuineIntel-2.7.11\lazylinker_ext\lazylinker_ext.pyd C:\Users\simon\AppData\Local\Theano\compiledir_Windows-10-10.0.14393-Intel64_Family_6_Model_94_Stepping_3_GenuineIntel-2.7.11\lazylinker_ext\mod.cpp -LD:\ProgramFiles\Entought\Canopy\App\appdata\canopy-1.7.4.3348.win-x86_64\libs -LD:\ProgramFiles\Entought\Canopy\App\appdata\canopy-1.7.4.3348.win-x86_64 -lpython27
# ---------------------------------------------------------------------------
# WindowsError                              Traceback (most recent call last)
# <ipython-input-69-3397704bd624> in <module>()
# ----> 1 import theano
#
# C:\Users\simon\AppData\Local\Enthought\Canopy\User\lib\site-packages\theano\__init__.pyc in <module>()
#      55      object2, utils
#      56
# ---> 57 import compile
#      58
#      59 from compile import \
#
# C:\Users\simon\AppData\Local\Enthought\Canopy\User\lib\site-packages\theano\compile\__init__.py in <module>()
#       1
# ----> 2 import function_module
#       3 from function_module import *
#       4
#       5 import mode
#
# C:\Users\simon\AppData\Local\Enthought\Canopy\User\lib\site-packages\theano\compile\function_module.py in <module>()
#      15 from theano import gof
#      16 from theano.gof.python25 import partial
# ---> 17 import mode as mode_module
#      18 from io import In, SymbolicInput, SymbolicInputKit, SymbolicOutput
#      19 from theano.configdefaults import config
#
# C:\Users\simon\AppData\Local\Enthought\Canopy\User\lib\site-packages\theano\compile\mode.py in <module>()
#       5 import numpy, theano
#       6 from theano import gof
# ----> 7 import theano.gof.vm
#       8 from theano.configparser import config, AddConfigVar, StrParam, EnumStr
#       9
#
# C:\Users\simon\AppData\Local\Enthought\Canopy\User\lib\site-packages\theano\gof\vm.py in <module>()
#     375
#     376 try:
# --> 377     import lazylinker_c
#     378     class CVM(lazylinker_c.CLazyLinker, VM):
#     379         def __init__(self, *args, **kwargs):
#
# C:\Users\simon\AppData\Local\Enthought\Canopy\User\lib\site-packages\theano\gof\lazylinker_c.py in <module>()
#      47             if not os.path.exists(loc):
#      48                 os.mkdir(loc)
# ---> 49             cmodule.gcc_module_compile_str(dirname, code, location=loc)
#      50             # Save version into the __init__.py file.
#      51             init_py = os.path.join(loc, '__init__.py')
#
# C:\Users\simon\AppData\Local\Enthought\Canopy\User\lib\site-packages\theano\gof\cmodule.pyc in gcc_module_compile_str(module_name, src_code, location, include_dirs, lib_dirs, libs, preargs)
#    1392
#    1393     try:
# -> 1394         p = subprocess.Popen(cmd, stderr=subprocess.PIPE)
#    1395         compile_stderr = p.communicate()[1]
#    1396     except Exception:
#
# D:\ProgramFiles\Entought\Canopy\App\appdata\canopy-1.7.4.3348.win-x86_64\lib\subprocess.pyc in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags)
#     708                                 p2cread, p2cwrite,
#     709                                 c2pread, c2pwrite,
# --> 710                                 errread, errwrite)
#     711         except Exception:
#     712             # Preserve original exception in case os.close raises.
#
# D:\ProgramFiles\Entought\Canopy\App\appdata\canopy-1.7.4.3348.win-x86_64\lib\subprocess.pyc in _execute_child(self, args, executable, preexec_fn, close_fds, cwd, env, universal_newlines, startupinfo, creationflags, shell, to_close, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite)
#     956                                          env,
#     957                                          cwd,
# --> 958                                          startupinfo)
#     959             except pywintypes.error, e:
#     960                 # Translate pywintypes.error to WindowsError, which is
#
# WindowsError: [Error 2] Das System kann die angegebene Datei nicht finden

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-af8c77e09569> in <module>()
# ----> 1 len(a)
#
# TypeError: 'int' object is not callable

# %%
values = translateBrands(values)

# %%
values
array = np.array(10)

# %%
array
# Out:
# array(10)

# %%
import theano
