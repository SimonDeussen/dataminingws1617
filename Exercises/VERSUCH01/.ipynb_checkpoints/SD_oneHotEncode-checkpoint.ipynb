# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random

DATA_PATH_SD = 'E:\\DM Exercises\\Data Mining DATA\\VERSUCH01\\'
DATA_PATH_DT = '/home/danieltremer/Desktop/'

testdata = pd.read_csv(DATA_PATH_SD + "bigmerge.csv")
testdata = testdata.drop("Unnamed: 0", 1)
testdata = testdata.drop("gender", 1)
testdata = testdata.drop("age", 1)

# %%
testdata
# Out:
#                    device_id   group phone_brand     device_model  \
# 0          29182687948017175    M39+          小米           红米note
# 1       -4833982096941402721    M39+          魅族          MX4 Pro
# 2       -8195816569128397698    M39+          锤子             坚果手机
# 3        2164896744275908815    M39+          三星    Galaxy Note 3
# 4       -2975746691063869447  F33-42          华为         荣耀6 Plus
# 5        -540200947281428061    M39+          华为           Mate 7
# 6        3929259450001563794  F29-32          三星    Galaxy Note 3
# 7         347753157502768291  F24-26          小米           小米note
# 8        1513402990297914172    F43+          魅族               魅蓝
# 9        4824807694869766674  M29-31          华为              荣耀7
# 10      -6515269256063189537  M32-38          魅族              MX5
# 11       1946302634062517988    M39+          魅族           魅蓝NOTE
# 12      -2876670182687327494  F27-28        OPPO          N1 Mini
# 13      -1053657946037918624  F29-32          华为           Mate 7
# 14      -2603528729536808786    M39+          华为           Mate 7
# 15       5730785014341775081  M27-28          华为           Mate 7
# 16        476363564643571851  M32-38          魅族              MX4
# 17        282723060580691300  M29-31          华为        Ascend P8
# 18       4657697113512107583  M32-38          华为              荣耀6
# 19       2700552381152892177  M32-38        vivo              X5M
# 20       -906684455621397904    M39+          华为              荣耀6
# 21      -8129655779260576690  M23-26          小米             MI 4
# 22       2530700676011415660  M23-26          魅族          MX4 Pro
# 23       8879781925351041880    M39+          小米             MI 3
# 24      -7893824316001319074    M39+          华为           Mate 7
# 25      -1377363553664296477  M32-38          小米            MI 2A
# 26       -669426881946113309    M39+          华为              荣耀6
# 27      -8396990124102864301    F43+          华为        Ascend P8
# 28      -1906081829099736481  M29-31          华为           Mate 7
# 29       7329991885099258124  M32-38          乐视          超级手机Max
# ...                      ...     ...         ...              ...
# 1523352 -6090702707636116922    F23-          酷派             5892
# 1523353 -2968245526185589497    M22-          乐视           超级手机1s
# 1523354  2539411400447309846  F24-26          小米             红米1S
# 1523355  3101106144238649232  M32-38          华为         荣耀6 Plus
# 1523356 -6552359867580708786  M23-26          华为           Mate 7
# 1523357    35172350775627890  M32-38        vivo          X6 Plus
# 1523358  6219649997182301907  M23-26          小米          红米Note2
# 1523359    35172350775627890  M32-38        vivo          X6 Plus
# 1523360  3037914034795861676  F24-26        OPPO              A31
# 1523361 -1375555536943139651  M32-38          三星        Galaxy A7
# 1523362 -1469837310329850172  F27-28        vivo             X6 D
# 1523363   275917241569480314    M39+          华为              荣耀6
# 1523364  7204701083846184011    F23-        OPPO            R2017
# 1523365  8455251085115456476    M22-          三星   Galaxy S6 Edge
# 1523366  6209124778255342976  M29-31          小米          note顶配版
# 1523367 -4383365898722247667  M32-38          三星  Galaxy S6 Edge+
# 1523368 -7509127332023928061  M27-28          金立               E8
# 1523369  8536812499298120447  M27-28          三星      Galaxy Note
# 1523370 -3566023943424409390  M23-26        OPPO          R7 Plus
# 1523371  3617573828659934318    M22-        OPPO              R1C
# 1523372 -4316181811910217163  M23-26          魅族          MX4 Pro
# 1523373  5453686748182522264  M32-38          华为           Mate 7
# 1523374  6390048816899554783  M32-38          三星            G3818
# 1523375  5197530142143050644  F29-32        OPPO              A53
# 1523376  5197530142143050644  F29-32        OPPO              A53
# 1523377  5197530142143050644  F29-32        OPPO              A53
# 1523378 -6769818128760047181    F43+         努比亚           Z9 Max
# 1523379 -2168282823630363487    M39+          三星    Galaxy Note 3
# 1523380  4614591682572420196  M23-26          三星        Galaxy S5
# 1523381 -1968916917562323751  M32-38          小米           红米note
#
#                           category
# 0                     Custom label
# 1                     Custom label
# 2                     Custom label
# 3                     Custom label
# 4                     Custom label
# 5                     Custom label
# 6                     Custom label
# 7                     Custom label
# 8                     Custom label
# 9                     Custom label
# 10                    Custom label
# 11                    Custom label
# 12                    Custom label
# 13                    Custom label
# 14                    Custom label
# 15                    Custom label
# 16                    Custom label
# 17                    Custom label
# 18                    Custom label
# 19                    Custom label
# 20                    Custom label
# 21                    Custom label
# 22                    Custom label
# 23                    Custom label
# 24                    Custom label
# 25                    Custom label
# 26                    Custom label
# 27                    Custom label
# 28                    Custom label
# 29                    Custom label
# ...                            ...
# 1523352                     puzzel
# 1523353                     puzzel
# 1523354                     puzzel
# 1523355                      Trust
# 1523356   Guard tower defense game
# 1523357                      Senki
# 1523358                      Senki
# 1523359                    Romance
# 1523360                    Romance
# 1523361                    Romance
# 1523362            raising up game
# 1523363                   Jin Yong
# 1523364                   Jin Yong
# 1523365                   Jin Yong
# 1523366                   Jin Yong
# 1523367                     search
# 1523368               Martial arts
# 1523369                     effort
# 1523370       Children puzzle game
# 1523371         Beach landing game
# 1523372                     Estate
# 1523373  Outlaws of the Marsh game
# 1523374  Outlaws of the Marsh game
# 1523375             game-game type
# 1523376             game-Art Style
# 1523377       game-Gem Elimination
# 1523378                   RPG game
# 1523379                   RPG game
# 1523380                    mesasge
# 1523381                      Harem
#
# [1523382 rows x 5 columns]

# %%
def convertDFToDict(df_input):
    labels = {}
    values = {}
    print len(labels)
    for i in range(0,len(testdata)):
        labels[i] = testdata['group'][i]
        values[i] = (testdata['device_id'][i], testdata['phone_brand'][i], 
                      testdata['device_model'][i], testdata['category'][i])
    return labels, values

# %%
labels, values = convertDFToDict(testdata)
# Out:
# 0

# %%
from sklearn.preprocessing import OneHotEncoder
enc = OneHotEncoder()
enc.fit(tmp)  
OneHotEncoder(categorical_features=[False, True, True, True],
       handle_unknown='error', n_values='auto', sparse=True)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-96-7d4555fa391f> in <module>()
# ----> 1 from sklearn.preprocessing import OneHotEncoder
#       2 enc = OneHotEncoder()
#       3 enc.fit(tmp)
#       4 OneHotEncoder(categorical_features=[False, True, True, True],
#       5        handle_unknown='error', n_values='auto', sparse=True)
#
# ImportError: No module named sklearn.preprocessing

# %%
tmp = {}
for i in range(0,100):
    tmp[i] = values[i]
