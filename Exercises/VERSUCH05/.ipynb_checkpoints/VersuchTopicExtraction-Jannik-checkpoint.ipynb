# %% [markdown]
# # Topic Extraction in Newsfeeds
# * Autor: Prof. Dr. Johannes Maucher
# * Datum: 17.11.2015
#
# [Übersicht Ipython Notebooks im Data Mining Praktikum](Data Mining Praktikum.html)
#
# # Einführung
# ## Lernziele:
#
# In diesem Versuch sollen Kenntnisse in folgenden Themen vermittelt werden:
#
# * __RSS Feeds:__ Struktur von RSS Feeds analysieren und parsen mit dem _Universal Feed Parser_.
# * __Dokument Analyse:__ Die Häufigkeit aller Worte in einem Dokument (Inhalt des RSS Feeds) zählen und in einem Array verwalten.
# * __Merkmalsextraktion:__ Bestimmung von Merkmalen (hier auch: __Topics__) (Allgemein spricht man von Merkmalen. Im Fall, dass die NNMF auf Dokumente angewandt wird, werden die Merkmale auch mit __Topics__ oder __Themen__ bezeichnet) mit der \emph{Non Negative Matrix Factorization}.
# * __Zuordnung__: Wie setzen sich die Topics aus den Wörtern zusammen? Wie stark sind die gefundenen Topics in den Artikeln vertreten?
# * __Dokument Clustering:__ Mit der NNMF kann auch ein Clustering realisiert werden. Jeder Topic repräsentiert ein Cluster. Jedes Dokument wird dem Cluster zugeordnet, dessen Topic am stärksten in ihm vertreten ist.
#
# Sämtliche Verfahren und Algorithmen werden in Python implementiert.
#
# ## Theorie zur Vorbereitung
#
# Stellen Sie sich vor Sie möchten in eine eigene Webseite die RSS Feeds einer Menge von Nachrichtenservern einbinden. Da die unterschiedlichen Server wahrscheinlich Artikel zu den gleichen Themen anbieten, werden die Inhalte einiger Artikel ähnlich sein. Mit der __Nicht Negativen Matrixfaktorisierung (NNMF)__ kann für eine große Menge von Dokumenten eine Menge von Themen (Topics) ermittelt werden, auf die sich die Dokumente beziehen. Damit ist es u.a. möglich
# * die Dokumente thematisch zu ordnen
# * zu jedem Thema nur ein Dokument anzuzeigen
#
# ### Ähnlichkeiten bestimmen und relevante Merkmale extrahieren
#
# Eine Sammlung von Dokumenten - in diesem Versuch die Menge aller Nachrichten der angegebenen Feeds - kann in einer Artikel/Wort-Matrix repräsentiert werden. Jede Zeile dieser Matrix gehört zu einem Dokument. Für jedes Wort, das mindestens in einem der Dokumente vorkommt, ist eine Spalte vorgesehen. Das Matrixelement in Zeile $i$, Spalte $j$ beschreibt wie häufig das Wort in Spalte $j$ im zur Zeile $i$ gehörenden Dokument vorkommt.
#
# Unter der Annahme, dass Artikel umso ähnlicher sind, je mehr Worte in diesen gemeinsam vorkommen, kann auf der Grundlage dieser Matrix die Ähnlichkeit zwischen den Artikeln berechnet werden. Hierzu könnte die Matrix z.B. einfach einem _Hierarchischen Clustering_ übergeben werden. Das hierarchische Clustering weist jedoch im Fall einer großen Menge von zu vergleichenden Objekten zwei wesentliche Nachteile auf: Erstens ist die wiederholte Berechnung der Distanzen zwischen allen Artikeln/Clustern extrem rechenaufwendig, zweitens ist die Darstellung einer großen Anzahl von Objekten im Dendrogramm nicht mehr übersichtlich.
#
# Für das Auffinden von Assoziationen zwischen Dokumenten hat sich in den letzten Jahren die Methode der __Nicht-Negativen Matrix Faktorisierung (NNMF)__ etabliert. Mit dieser Methode kann eine Menge von wesentlichen Merkmalen berechnet werden, anhand derer sich die Dokumente clustern lassen, d.h. Dokumente des gleichen Clusters repräsentieren das gleiche Merkmal (Thema). Ein solches Merkmal wird durch eine Menge von Worten beschrieben, z.B. $\{$ _Paris, terror, IS_ $\}$  oder $\{$_refugee, syria, border_ $\}$. Neben der Merkmalsextraktion stellt die relativ geringe Komplexität einen weiteren Vorteil der NNMF dar. Durch die Darstellung der Artikel/Wort-Matrix als Produkt von 2 Faktormatrizen müssen deutlich weniger Einträge gespeichert werden.
#
# ### Nicht Negative Matrixfaktorisierung: Die Idee
#
# Die Artikel/Wort-Matrix wird im Folgenden mit $A$ bezeichnet. Sie besitzt $r$ Zeilen und $c$ Spalten, wobei $r$ die Anzahl der Artikel und $c$ die Anzahl der relevanten Worte in der Menge aller Artikel ist. Durch Multiplikation der Matrix $A$ mit dem Vektor $v$ (_wordvec_: Vektor der alle relevanten Worte enthält) werden die Worte den Artikeln $a$ (_articletitles_: Vektor der alle Artikeltitel enthält) zugeordnet:
#
# $$
# a=A*v.
# $$
#
# Die Idee der NNMF besteht darin die Matrix $A$ als Produkt zweier Matrizen $W$ und $H$ darzustellen,
#
# $$
# A=W*H
# $$
#
# wobei alle Elemente in $W$ und $H$ größer oder gleich Null sein müssen. Die Matrixmultiplikation erfordert, dass die Anzahl der Zeilen $m$ in $H$ gleich der Anzahl der Spalten in $W$ sein muss.
# Durch die Faktorisierung der Matrix $A$ wird die Zuordnung der Wörter des Wortvektors $v$  zu den Artikeln des Vektors $a$ in zwei Stufen zerlegt.
#
# $$
# f = H*v
# $$
# $$
# a = W*f
# $$
#
# In der ersten Stufe werden durch die Multiplikation von $v$ mit der Matrix $H$ die Wörter einem sogenannten Merkmalsvektor $f$ mit $m$ Elementen zugewiesen. In der zweiten Stufe werden durch die Multiplikation des Merkmalsvektor $f$ mit der Matrix $W$ die einzelnen Merkmale den Artikeln in $a$ zugeordnet. Die Matrix $H$ definiert also aus welchen Wörtern die Merkmale gebildet werden. Sie wird deshalb __Merkmalsmatrix__ genannt. Die Matrix $W$ hingegen beschreibt mit welchem Gewicht die einzelnen Merkmale in den verschiedenen Artikeln auftreten. Sie wird deshalb __Gewichtungsmatrix__ genannt.
#
# Daraus folgt: Wenn eine Faktorisierung der Matrix $A$ gefunden wird, dann werden damit auch relevante Merkmale, also die Themen, definiert, hinsichtlich derer die Artikel effizient kategorisiert werden. Durch die Matrixfaktorisierung wird eine __Merkmalsextraktion__ realisiert.
#
# ### Berechnung der Matrixfaktoren
#
# Für die Berechnung der Faktoren wurde in [Lee, Algortihms for Non-negative Matrix Factorisation](http://papers.nips.cc/paper/1861-algorithms-for-non-negative-matrix-factorization.pdf) eine iterative Methode vorgestellt, die derzeit wohl am häufigsten angewandt wird und auch in dieser Übung implementiert werden soll. Der Algorithmus besteht aus folgenden Schritten:
# * Gebe die zu faktorisierende Matrix $A$ ein. $r$ sei die Anzahl der Zeilen und $c$ die Anzahl der Spalten von $A$.
# * Wähle die Anzahl $m$ der Merkmale, mit $m<c$. _Tipp:_ Für $m$ sollte zunächst ein Wert im Bereich $15$ bis $30$ gewählt werden.
# * Lege eine $m \times c$ Matrix $H$ an mit initial zufälligen Elementen (Anwendung der numpy Funktion _random.random()_)
# * Lege eine $r \times m$ Matrix $W$ an mit initial zufälligen Elementen (Anwendung der numpy Funktion _random.random()_)
# * Wiederhole bis maximale Anzahl der Iteration erreicht oder Kosten $k$ unter vordefinierter Schwelle:
#
# 	* Berechne aktuelles Produkt $B=W*H$ und bereche die Kostenfunktion
# 		$$
# 			k=\left\| A - B \right\|^2 = \sum\limits_{i,j} \left(A_{i,j} - B_{i,j}\right)^2
# 		$$
# 	* Anpassung der Matrix $H$ durch folgende Neuberechnung der Matrixelemente
#
# 		$$
# 		H_{i,j} := H_{i,j} \frac{(W^T*A)_{i,j}}{(W^T*W*H)_{i,j}}
# 		$$
#
# 	* __Nach__ der Anpassung der Matrix $H$: Anpassung der Matrix $W$ durch folgende Neuberechnung der Matrixelemente
#
# 		$$
# 		W_{l,i} := W_{l,i} \frac{(A*H^T)_{l,i}}{(W*H*H^T)_{l,i}}
# 		$$
#
# In [Lee, Algortihms for Non-negative Matrix Factorisation](http://papers.nips.cc/paper/1861-algorithms-for-non-negative-matrix-factorization.pdf) ist bewiesen, dass durch die o.g. Anpassungsroutinen die Kosten $k$ monoton abnehmen und in einem Minimum konvergieren. Der Algorithmus ist jedoch nicht optimal weil das gefundene Minimum ein lokales Minimum sein kann.

# %% [markdown]
#  ## Vor dem Versuch zu klärende Fragen
#
#  * Was versteht man unter Artikel/Wort-Matrix? Wie wird diese im aktuellen Versuch gebildet?

# %% [markdown]
# Eine Artikel/Wort Matrix besteht aus r Zeilen, die für die Artikel stehen und c Spalten die für alle Wörter in den Artikeln stehen. Die Werte innerhalb einer Zeile stehen für die Häufigkeit der jeweiligen Worte.

# %% [markdown]
# * Wie multipliziert man die Matrix
#     $$
#     A= \left( \begin{array}{cccc}
# a_{00} & a_{01} & a_{02} & a_{03} \\
# a_{10} & a_{11} & a_{12} & a_{13} \\
# a_{20} & a_{21} & a_{22} & a_{23}
# \end{array} \right)
#     $$
#     mit dem Vektor
#     $$
#     v=\left( \begin{array}{c}
# v_{0} \\
# v_{1} \\
# v_{2} \\
# v_{3}
# \end{array} \right)
#     $$

# %% [markdown]
# a = A &ast; v
#
#
# a = (a00&ast;v0 + a01&ast;v1 + a02&ast;v2 + a03&ast;v3)
#     (a10&ast;v0 + a11&ast;v1 + a12&ast;v2 + a13&ast;v3)
#     (a20&ast;v0 + a21&ast;v1 + a22&ast;v2 + a23&ast;v3)

# %% [markdown]
# * Was versteht man im Kontext der NNMF unter
#     * Merkmalsmatrix
#     * Gewichtsmatrix

# %% [markdown]
# Die Merkmalsmatrix ist eine Merkmal x Wort Matrix, die für ein Merkmal die Wörter festlegt, die dieses Merkmal ausmachen.
# Die Gewichtsmatrix ist eine Artikel x Merkmals Matrix, die für jeden Artikel die Gewichtung der einzelnen Mermale bestimmt, d.h. wie stark ein Merkmal in dem Artikel vertreten ist

# %% [markdown]
# * Wie definieren die Zeilen der Merkmalsmatrix die einzelnen Merkmale (Topics)?
# * Was definieren die Zeilen der Gewichtungsmatrix?

# %% [markdown]
# Eine Zeile der Merkmalsmatrix steht für ein gefundenes Merkmal.
# Eine Zeile steht der Gewichtungsmatrix steht für einen bestimmten Artikel.

# %% [markdown]
# * Wie werden in Numpy zwei Arrays (Typ numpy.array)
# 	* im Sinne der Matrixmultiplikation miteinander multipliziert?
# 	* elementweise multipliziert?
# * Wie wird die Transponierte eines Numpy-Arrays berechnet?

# %%
import numpy as np

a = np.matrix([[1, 1], 
               [1, 1]])

b = np.matrix([[0, 1], 
               [2, 0]])

# Matrixmultiplikation
print a * b

# Elementweise Multiplikation
print np.multiply(a, b)

# Matrix transponieren
print b.transpose()
# Out:
# [[2 1]
#  [2 1]]
# [[0 1]
#  [2 0]]
# [[0 2]
#  [1 0]]

# %% [markdown]
# # Versuchsdurchführung
# Die in diesem Versuch einzubindenden Feeds sind in der unten stehenden Liste _feedlist_ definiert. Die aus dem vorigen Vesuch bereits bekannte Funktion _stripHTML()_ ist ebenfalls gegeben:

# %%
import feedparser

feedlist=['http://feeds.reuters.com/reuters/topNews',
          'http://feeds.reuters.com/reuters/businessNews',
          'http://feeds.reuters.com/reuters/worldNews',
          'http://feeds2.feedburner.com/time/world',
          'http://feeds2.feedburner.com/time/business',
          'http://feeds2.feedburner.com/time/politics',
          'http://rss.cnn.com/rss/edition.rss',
          'http://rss.cnn.com/rss/edition_world.rss',
          'http://www.nytimes.com/services/xml/rss/nyt/GlobalHome.xml',
          'http://feeds.nytimes.com/nyt/rss/Business',
          'http://www.nytimes.com/services/xml/rss/nyt/World.xml',
          'http://www.nytimes.com/services/xml/rss/nyt/Economy.xml'
          ]

# %%
def stripHTML(h):
  p=''
  s=0
  for c in h:
    if c=='<': s=1
    elif c=='>':
      s=0
      p+=' '
    elif s==0: p+=c
  return p

# %% [markdown]
# ## Anlegen der Artikel/Wort-Matrix
#
# ### Die Funktion _getarticlewords()_
# Schreiben Sie eine Funktion _getarticlewords()_, die folgende Elemente zurückgibt:
#
# * _allwords:_ ist ein Dictionary dessen Keys die Worte aller gesammelten Artikel sind. Der zu jedem Key gehörende Wert ist die Anzahl, wie oft das Wort insgesamt vorkommt.
# * _articlewords:_ ist eine Liste mit so vielen Elementen wie Artikel in der Sammlung sind. Jedes Listenelement ist ein Dictionary, welches die Worte des jeweiligen Artikels als Key enthält und als Wert die Worthäufigkeit.
# * _articletitles_ ist eine Liste mit so vielen Elementen wie Artikel in der Sammlung sind. Jedes Element ist der Artikeltitel als String.
#
# Für das Parsing der Feeds soll wieder das Modul _feedparser_ eingesetzt werden. Die zu einer Nachricht gehörenden Wörter sollen die Wörter des Elements _title_ und die Wörter des Elements _description_ sein (siehe voriger Versuch). Allerdings sollen hier nicht alle Wörter eingebunden werden, sondern wie im vorigen Versuch eine Methode _getwords()_ implementiert werden, welche nur die _relevanten_ Wörter zurückgibt. Die Frage welche Wörter relevant sind ist nicht eindeutig beantwortbar. Sie können sich hierzu eigene Antworten einfallen lassen. Auf jeden Fall sollten aber die Stopwörter ignoriert werden. Hierzu kann z.B. die Stopwortliste von NLTK angewandt werden.
#
# Nachdem alle relevanten Wörter aller Nachrichten gesammelt sind, sollte eine weitere Bereinigung stattfinden, die
#
# * alle Wörter, die weniger als 4 mal vorkommen
# * alle Wörter, die in mehr als 30% aller Dokumente vorkommen
#
# entfernt.
#
# Durch dieses Herausfiltern nicht relevanter Wörter kann es vorkommen, dass einzelne Artikel keine relevanten Wörter mehr enthalten. Diese Artikel sollen dann ganz ignoriert werden. D.h. unter anderem, dass diese Artikel auch nicht in _articlewords_ und _articletitles_ erscheinen.

# %%
from nltk.corpus import stopwords
from nltk import word_tokenize
from itertools import dropwhile
from nltk.stem import WordNetLemmatizer
import re

# First version of getwords
def getwordsold(text):
    words = []
    for i in text.split():
        word = re.sub(r'\W+', '', i.lower())
        if len(word) > 4 and len(word) < 20:
            words.append(word)
            
    return words

# Improved version of getwords
def getwords(text):
    wnl = WordNetLemmatizer()
    custom_stopwords = {'great', 'this', 'like', 'it', 'next', 'thanks', 'much', 'what', 'with',
                    'were', 'need', 'more', 'word', 'say', 'here', 'very', 'these', 'take', 'every',
                    'come', 'week', 'thanks', 'with', 'week', 'year', 'day', 'great', 'thats', 'today',
                    'tomorrow', 'could', 'please', 'really', 'tonight', 'first', 'coming', 'though', 'although',
                    'amazing', 'awesome', 'might', 'monday', 'tuesday', 'wednesday', 'thursday', 'friday', 'saturday',
                    'sunday', 'weekend', 'month', 'using', 'night', 'going', 'people', 'thing', 'still', "think",
                    "looking", "right", "better", "thought", "never", "sound", "getting", "always",
                    "thank", "morning", "happy", "maybe", "pretty", "someone", "actually", "interesting", "little",
                    "quite", "point", "start", 'reuters'}
    stop = set(stopwords.words('english'))
    stop.update(custom_stopwords)
    return [wnl.lemmatize(i.lower()) for i in word_tokenize(text) if i.lower() not in stop and len(i) > 4 and len(i) < 20]

def findIrrelevant(words, min_frequency, max_percentage):
    word_sum = sum(words.values())
    return {word for word, frequency in words.items() if frequency <= min_frequency or float(frequency)/word_sum > max_percentage}

def getarticlewords(feed):
    allwords = dict()
    articlewords = list()
    articletitles = list()
    f=feedparser.parse(feed)
    for article in f.entries:
        if 'description' in article and 'title' in article:
            fulltext = stripHTML(article.title + ' ' + article.description)
            words = getwords(fulltext)
            articleword = dict()
            for word in words:
                if word in articleword:
                    articleword[word] += 1
                else:
                    articleword[word] = 1
                    
                if word in allwords:
                    allwords[word] += 1
                else:
                    allwords[word] = 1
            articlewords.append(articleword)
            articletitles.append(article.title)
            
    irrelevant_words = findIrrelevant(allwords, 2, 0.5)
    
    for word in irrelevant_words:
        del allwords[word]
        
        for articleword in articlewords:
            if word in articleword:
                del articleword[word]
                
    if not allwords:
        return None
    
    articlewords, articletitles = zip(*[(articleword, title) for articleword, title in zip(articlewords, articletitles) if articleword])
        
    return (allwords, np.array(articlewords), np.array(articletitles))

# %% [markdown]
# ### findIrrelevant( )
#
# Wir haben für den parameter `min_frequency` 2 und für den Parameter `max_percentage` 0.5 gewählt, da ansonsten nicht genügend Wörter gefunden werden um passende Topics zu generieren.

# %% [markdown]
# ### Die Funktion _makematrix()_
# Schreiben Sie eine Funktion _makematrix()_, die aus dem Dictionary _allwords_ und der Liste _articlewords_ (vorige Aufgabe) die Artikel-/Wort-Matrix generiert. Die Einträge in der Matrix sollen die Häufigkeiten der Wörter im jeweiligen Dokument sein (term frequency tf). Die Artikel-/Wort-Matrix soll als 2-dimensionales Numpy Array angelegt werden.

# %%
def makematrix(allwords, articlewords):
    words = allwords.keys()
    article_word_matrix = np.zeros((len(articlewords), len(words)))
    for i in range(len(article_word_matrix)):
        row = article_word_matrix[i]
        current_articlewords = articlewords[i]
        for word in current_articlewords.keys():
            row[words.index(word)] = current_articlewords[word]
    return (np.matrix(article_word_matrix), words)

# %% [markdown]
# ## Die Nicht Negative Matrix Faktorisierung
# Die Implementierung der NNMF ist entsprechend der Beschreibung im Theoriekapitel durchzuführen.
#
# * Implementieren Sie die Funktion _cost(A,B)_. Dieser Funktion werden zwei Numpy-Matrizen $A$ und $B$ übergeben. Zurück geliefert werden die nach oben angegebener Formel berechneten Kosten $k$. Diese Funktion wird von der im folgenden beschriebenen Funktion _nnmf(A,m,it)_ benutzt.
# * Implementieren Sie die Funktion __nnmf(A,m,it)__. In dieser Funktion soll der oben beschriebene Algorithmus für die Nicht-negative Matrix Faktorisierung ausgeführt werden. Der Funktion wird die zu faktorisierende Matrix $A$, die Anzahl der Merkmale $m$ und die Anzahl der Iterationen $it$ übergeben. Die Funktion gibt die gefundenen Faktoren $W$ und $H$ zurück. In jeder Iteration sollen mit der Funktion __cost(A,B)__ die Kosten berechnet werden. Sobald die Kostenabnahme pro 10 Iterationen kleiner als $2$ ist oder eine maximale Anzahl von Iterationen ($maxIt=200$) erreicht ist, soll der Algorithmus mit der Rückgabe der Faktoren $W$ und $H$ terminieren.
#
#
# Tipp für die Implementierung elementweiser Operationen von Matrizen: Für elementweise Operationen müssen in Python/Numpy nicht alle Elemente über Schleifen explizit berechnet werden. Eine elementweise Anpassung aller Matrixelemente kann kompakt programmiert werden indem die beteiligten Matrizen für diese Operationen als Arrays implementiert werden. Sollen z.B. die beiden gleich großen Numpy Arrays $U$ und $V$ elementweise multipliziert werden, dann wäre der entsprechende Programmcode einfach _U*V_.

# %%
def cost(A, B):
    return np.sum(np.square(A - B))
    
def nnmf(A, m, it, threshold=2):
    (r, c) = A.shape
    
    if not m < c:
        raise ValueError("m must be smaller than the width of A")
         
    B = None
    
    cost_iteration = 0
    cost_start = None
    cost_current = None
    
    H = np.matrix(np.random.random((m, c)))
    W = np.matrix(np.random.random((r, m)))

    for i in range(it): 
        cost_iteration += 1
        
        if cost_iteration == 10:
            if cost_start - cost_current > threshold:
                cost_iteration = 0
                cost_start = cost_current
            else:
                break
      
        B = W * H
        
        _cost = cost(A, B)
        
        if not cost_start:
            cost_start = _cost
        
        cost_current = _cost
        
        H = np.multiply(H, (W.T * A)/(W.T*W*H))
        W = np.multiply(W, (A * H.T)/(W*H*H.T))
        
        if it - 1 == i:
            print "Reached maximum amount of iterations"
    
    return (W, H)

# %% [markdown]
# ## Anzeige der Merkmale und der Gewichte
#
# Im vorigen Abschnitt wurde die Merkmalsmatrix $H$ und die Gewichtsmatrix $W$ berechnet. Diese Matrizen können natürlich am Bildschirm ausgegeben werden, was jedoch nicht besonders informativ ist. Aus den Matrizen können jedoch die Antworten für die folgenden interessanten Fragen berechnet werden:
#
# * In welchen Artikeln sind welche Merkmale stark vertreten?
# * Wie lassen sich die insgesamt $m$ Merkmale beschreiben, so dass aus dieser Merkmalsbeschreibung klar wird, welches Thema den Artikeln, in denen das Merkmal stark vertreten ist, behandelt wird?
#
# Die Antwort auf die erste Frage ergibt sich aus der Gewichtsmatrix $W$. Für die Beantwortung der zweiten Frage wird die Merkmalsmatrix $H$ herangezogen.
#
#
#
# ### Beschreibung der Merkmale
#
# Die Merkmalsmatrix $H$ beschreibt, wie stark die Worte aus _wordvec_ in jedem Merkmal enthalten sind. Jede Zeile von $H$ gehört zu einem Merkmal, jede Spalte von $H$ gehört zu einem Wort in _wordvec_.
#
# Es bietet sich an jedes Merkmal einfach durch die $N=6$ Wörter aus _wordvec_ zu beschreiben, welche am stärksten in diesem Merkmal enthalten sind. Hierzu muss für jedes Merkmal die entsprechende Zeile in $H$ nach den $N=6$ größten Werten durchsucht bzw. geordnet werden. Die entsprechenden Spalten dieser Matrixelemente verweisen dann auf die $N=6$ wichtigsten Worte des Merkmals.
#
# Tipp für die Implementierung: Legen Sie für jedes Merkmal $i$ eine Liste an. Die Listenlänge ist durch die Anzahl der Worte in _wordvec_ (d.h. die Anzahl der Spalten in $H$) gegeben. Jedes Listenelement $j$ enthält selbst wieder 2 Elemente: An erster Stelle den entsprechenden Wert $H_{i,j}$ der Merkmalsmatrix, an der zweiten Stelle das $j.$-te Wort in _wordvec_. Nachdem die Liste angelegt ist, kann sie mit _listname.sort()_ in aufsteigender Reihenfolge sortiert werden. Die abnehmende Sortierung erhält man mit _listname.sort().reverse()_. Danach geben die $N=6$ ersten Listenelemente die für das Merkmal $i$ wichtigsten Worte an.
#
#
# ### Präsenz der Merkmale in den Artikeln
#
# Die Gewichtsmatrix $W$ beschreibt, wie stark die $m$ Merkmale in den Artikeln aus _articletitles_ enthalten sind. Jede Zeile von $W$ gehört zu einem Artikel, jede Spalte von $W$ gehört zu einem Merkmal.
# Die Berechnung der $M=2$ gewichtigsten Merkmale für jeden Artikel in _articletitles_ kann analog zu der oben beschriebenen Berechnung der $N=6$ wichtigsten Worte eines Merkmals berechnet werden.
#
#
# ### Implementierung
#
# Implementieren Sie eine Funktion _showfeatures(w,h,titles,wordvec)_, welche wie oben beschrieben für jeden Artikel die $M=2$ wichtigsten Merkmale am Bildschirm ausgibt. Dabei soll jedes Merkmal durch die 6 wichtigsten Wörter dieses Merkmals angegeben werden. Siehe Beispielausgabe unten.
#
# Übergabeparameter der Funktion sind die Merkmalsmatrix $H$, die Gewichtungsmatrix $W$, die Liste aller Artikeltitel _articletitles_ und die Liste aller Worte _wordvec_.
#
#
# Beispiel fuer Ausgabe:

# %% [markdown]
# [(13.54131155883748, 13, u'Putin vows payback after confirmation of Egypt plane bomb'),
#
# (2.2466669548146254, 9, u'Putin vows payback after confirmation of Egypt plane bomb')]
#
# ----- ['plane', 'egypt', 'russia', 'month', 'killing', 'putin']
#
# ----- ['airport', 'russian', 'crash', 'egypt', 'security', 'officials']

# %% [markdown]
# Die Ausgabe ist wie folgt zu interpretieren:
# * Für den Artikel _Putin vows payback after confirmation of Egypt plane bomb_ ist
#     * das wichtigste Merkmal durch die 6 Wörter _plane_, _egypt_, _russia_, _month_, _killing_, _putin_ definiert. Das Gewicht dieses Merkmals im Artikel ist 13.54
#     * das zweitwichtigste Merkmal durch die 6 Wörter _airport_, _russian_, _crash_, _egypt_, _security_, _officials_ definiert. Das Gewicht dieses Merkmals im Artikel ist 2.24

# %%
NUM_TOPICS = 10
NUM_ITERATIONS = 50

def getarticlefeatures(w, titles):
    return zip([sorted(zip(article, range(len(article))), reverse=True)[:2] for article in np.array(w)], titles)


def showfeatures(w, h, titles, wordvec):
    features = [(sorted(zip(feature, wordvec), reverse=True))[:6] for feature in np.array(h)]
    article_features = getarticlefeatures(w, titles)
    for feature_weights, article in article_features:
        print feature_weights, article
        for weight, feature_index in feature_weights:
            print '-------', zip(*features[feature_index])[1]
    return features
    
def runnmf(topic_count, iterations):
    for feed in feedlist:
        article_words = getarticlewords(feed)
        if article_words:
            matrix, wordvec = makematrix(article_words[0], article_words[1])
            if (matrix.shape[1] > NUM_TOPICS):
                W, H = nnmf(matrix, topic_count, iterations)
                features = showfeatures(W, H, article_words[2], wordvec)
                
runnmf(NUM_TOPICS, NUM_ITERATIONS)
# Out:
# [(3.632850907959579, 0), (3.9694590170459952e-10, 5)] Aleppo evacuation delayed as rebels blame Iran
# ------- (u'aleppo', u'aircraft', u'china', u'state', u'trump', u'policy')
# ------- (u'thicke', u'price', u'department', u'energy', u'trump', u'president-elect')
# [(4.1593412070559079, 6), (4.1153259405964784, 7)] U.S. Energy Department balks at Trump request for names on climate change
# ------- (u'department', u'energy', u'president-elect', u'washington', u'donald', u'trump')
# ------- (u'trump', u'energy', u'department', u'donald', u'washington', u'president-elect')
# [(5.4345925668093837, 3), (0.18767649179436738, 8)] Fed set to hike rates, policy outlook now hinges on Trump presidency
# ------- (u'outlook', u'policy', u'washington', u'trump', u'secretary', u'donald')
# ------- (u'trump', u'state', u'policy', u'president-elect', u'donald', u'washington')
# [(4.0247152560475756, 2), (0.63426711896760957, 8)] Trump chooses congressman, former SEAL Zinke as interior secretary
# ------- (u'secretary', u'trump', u'washington', u'president-elect', u'donald', u'state')
# ------- (u'trump', u'state', u'policy', u'president-elect', u'donald', u'washington')
# [(4.8163648606832021, 4), (0.0057648792162604701, 1)] U.S. ready to confront Beijing on South China Sea: admiral
# ------- (u'china', u'state', u'trump', u'secretary', u'donald', u'president-elect')
# ------- (u'aircraft', u'state', u'policy', u'trump', u'secretary', u'washington')
# [(1.1860652870003388, 3), (1.0094135317500847e-08, 9)] Asia resigned to Fed hike, uptight on rate outlook
# ------- (u'outlook', u'policy', u'washington', u'trump', u'secretary', u'donald')
# ------- (u'price', u'trump', u'washington', u'policy', u'secretary', u'president-elect')
# [(4.3499928509204091, 8), (1.6141762136855442, 2)] Senate fight looms after Trump taps Exxon CEO as top U.S. diplomat
# ------- (u'trump', u'state', u'policy', u'president-elect', u'donald', u'washington')
# ------- (u'secretary', u'trump', u'washington', u'president-elect', u'donald', u'state')
# [(5.0803725363100218, 9), (6.5349195646958333e-09, 5)] Manhattan apartment sales prices top $2 million for first time: survey
# ------- (u'price', u'trump', u'washington', u'policy', u'secretary', u'president-elect')
# ------- (u'thicke', u'price', u'department', u'energy', u'trump', u'president-elect')
# [(5.070370432234462, 1), (0.0038398341730233898, 4)] U.S. grounds Osprey aircraft in Japan after Okinawa crash
# ------- (u'aircraft', u'state', u'policy', u'trump', u'secretary', u'washington')
# ------- (u'china', u'state', u'trump', u'secretary', u'donald', u'president-elect')
# [(5.174715041280721, 5), (0.0, 9)] Actor Alan Thicke, dad on 'Growing Pains,' dead at 69
# ------- (u'thicke', u'price', u'department', u'energy', u'trump', u'president-elect')
# ------- (u'price', u'trump', u'washington', u'policy', u'secretary', u'president-elect')
# [(4.8364921178215319, 3), (0.00053488395734998119, 0)] Aleppo: New shelling reported and civilians have no way out
# ------- (u'aleppo', u'according', u'world', u'would', u'agency', u'state')
# ------- (u'world', u'state', u'movie', u'controversial', u'space', u'donald')
# [(4.3458227139326935, 3), (0.0022357337193792863, 0)] Photos: Before the war
# ------- (u'aleppo', u'according', u'world', u'would', u'agency', u'state')
# ------- (u'world', u'state', u'movie', u'controversial', u'space', u'donald')
# [(2.1612450668770089, 3), (2.1095470760792545, 0)] Look back: 5 years to ruins
# ------- (u'aleppo', u'according', u'world', u'would', u'agency', u'state')
# ------- (u'world', u'state', u'movie', u'controversial', u'space', u'donald')
# [(2.1729113518150789, 3), (0.0011186668411606435, 0)] Opinion: We failed
# ------- (u'aleppo', u'according', u'world', u'would', u'agency', u'state')
# ------- (u'world', u'state', u'movie', u'controversial', u'space', u'donald')
# [(2.1729113543632947, 3), (0.0011182711235559635, 0)] 'Goodbye' messages
# ------- (u'aleppo', u'according', u'world', u'would', u'agency', u'state')
# ------- (u'world', u'state', u'movie', u'controversial', u'space', u'donald')
# [(4.2178380613697852, 0), (6.0247750506020581e-09, 4)] The islands where World War II never ended
# ------- (u'world', u'state', u'movie', u'controversial', u'space', u'donald')
# ------- (u'thicke', u'trump', u'donald', u'china', u'state', u'president-elect')
# [(9.123650108335827, 4), (2.4085078720832906e-09, 7)] Actor Alan Thicke dead at 69
# ------- (u'thicke', u'trump', u'donald', u'china', u'state', u'president-elect')
# ------- (u'human', u'space', u'according', u'state', u'world', u'thicke')
# [(1.6473317480632808, 9), (0.0078764265511961432, 2)] Why voters are flocking to Holland's Trump
# ------- (u'trump', u'donald', u'state', u'president-elect', u'controversial', u'china')
# ------- (u'agency', u'president-elect', u'donald', u'trump', u'would', u'movie')
# [(4.9281505266741839, 9), (2.5533393539152933, 0)] Why Trump's State pick is so controversial
# ------- (u'trump', u'donald', u'state', u'president-elect', u'controversial', u'china')
# ------- (u'world', u'state', u'movie', u'controversial', u'space', u'donald')
# [(5.3028604146399152, 9), (1.1809766538454272, 2)] Kanye West goes to Trump Tower
# ------- (u'trump', u'donald', u'state', u'president-elect', u'controversial', u'china')
# ------- (u'agency', u'president-elect', u'donald', u'trump', u'would', u'movie')
# [(1.8204995032292548, 8), (0.12533787086783796, 9)] Protests erupt over 20-year austerity plan
# ------- (u'woman', u'controversial', u'protest', u'state', u'donald', u'world')
# ------- (u'trump', u'donald', u'state', u'president-elect', u'controversial', u'china')
# [(6.6638021204047062, 2), (0.033329748406170402, 6)] Perry to run agency he wanted to ax
# ------- (u'agency', u'president-elect', u'donald', u'trump', u'would', u'movie')
# ------- (u'china', u'donald', u'would', u'trump', u'world', u'child')
# [(0.91705108820573256, 5), (0.31166587203139923, 2)] Spider species named for Harry Potter hat
# ------- (u'rocket', u'movie', u'space', u'state', u'president-elect', u'donald')
# ------- (u'agency', u'president-elect', u'donald', u'trump', u'would', u'movie')
# [(8.4309995684756256, 8), (2.750128450771502e-06, 9)] UN drops Wonder Woman
# ------- (u'woman', u'controversial', u'protest', u'state', u'donald', u'world')
# ------- (u'trump', u'donald', u'state', u'president-elect', u'controversial', u'china')
# [(0.49065959438494577, 3), (3.7853151009792431e-18, 7)] Gross things happen when you run
# ------- (u'aleppo', u'according', u'world', u'would', u'agency', u'state')
# ------- (u'human', u'space', u'according', u'state', u'world', u'thicke')
# [(0.39255427954634475, 8), (4.1164013270594897e-305, 5)] Pipeline leaks 130,000 gallons of crude oil
# ------- (u'woman', u'controversial', u'protest', u'state', u'donald', u'world')
# ------- (u'rocket', u'movie', u'space', u'state', u'president-elect', u'donald')
# [(2.0675584272727305, 9), (0.45712227705921532, 2)] Best new cars of 2016
# ------- (u'trump', u'donald', u'state', u'president-elect', u'controversial', u'china')
# ------- (u'agency', u'president-elect', u'donald', u'trump', u'would', u'movie')
# [(5.8142520120501633, 7), (0.37429850503659418, 3)] Report: Military set fire to towns in Myanmar
# ------- (u'human', u'space', u'according', u'state', u'world', u'thicke')
# ------- (u'aleppo', u'according', u'world', u'would', u'agency', u'state')
# [(4.2178380613697852, 0), (5.9791836370319115e-09, 4)] The best league in the world?
# ------- (u'world', u'state', u'movie', u'controversial', u'space', u'donald')
# ------- (u'thicke', u'trump', u'donald', u'china', u'state', u'president-elect')
# [(8.5308991006073516, 5), (0.075715696068770474, 7)] NASA to drop a rocket from a plane
# ------- (u'rocket', u'movie', u'space', u'state', u'president-elect', u'donald')
# ------- (u'human', u'space', u'according', u'state', u'world', u'thicke')
# [(2.1749739634884637, 0), (1.4611547922091421, 7)] World's best bathrooms
# ------- (u'world', u'state', u'movie', u'controversial', u'space', u'donald')
# ------- (u'human', u'space', u'according', u'state', u'world', u'thicke')
# [(3.7403822487611014, 1), (0.0, 9)] In Chicago, your home is the most likely place to get killed
# ------- (u'child', u'china', u'trump', u'donald', u'would', u'agency')
# ------- (u'trump', u'donald', u'state', u'president-elect', u'controversial', u'china')
# [(2.2413108612762302, 0), (0.80133051176236525, 5)] Star Wars: Revenge of the Myth
# ------- (u'world', u'state', u'movie', u'controversial', u'space', u'donald')
# ------- (u'rocket', u'movie', u'space', u'state', u'president-elect', u'donald')
# [(3.8431680793379446, 2), (1.5276993809046273, 9)] When government is run like a business
# ------- (u'agency', u'president-elect', u'donald', u'trump', u'would', u'movie')
# ------- (u'trump', u'donald', u'state', u'president-elect', u'controversial', u'china')
# [(12.692956213392728, 6), (0.82366143824454585, 9)] Don't play chicken with China
# ------- (u'china', u'donald', u'would', u'trump', u'world', u'child')
# ------- (u'trump', u'donald', u'state', u'president-elect', u'controversial', u'china')
# [(1.6471928993905092, 9), (0.0081634769677412181, 2)] Why Exxon chief is exactly the wrong man for Trump
# ------- (u'trump', u'donald', u'state', u'president-elect', u'controversial', u'china')
# ------- (u'agency', u'president-elect', u'donald', u'trump', u'would', u'movie')
# [(6.0581185696515085, 6), (3.2176729430158755, 9)] Trump can't afford to lose his fight against China
# ------- (u'china', u'donald', u'would', u'trump', u'world', u'child')
# ------- (u'trump', u'donald', u'state', u'president-elect', u'controversial', u'china')
# [(3.7403822487611014, 1), (0.0, 9)] Saving children from life on the streets
# ------- (u'child', u'china', u'trump', u'donald', u'would', u'agency')
# ------- (u'trump', u'donald', u'state', u'president-elect', u'controversial', u'china')
# [(0.62874922531342436, 2), (0.42909609036170332, 6)] Canadian teenagers sold for sex
# ------- (u'agency', u'president-elect', u'donald', u'trump', u'would', u'movie')
# ------- (u'china', u'donald', u'would', u'trump', u'world', u'child')
# [(3.806519011398168, 1), (2.5988590335768089, 6)] Girls drugged and sold as child brides
# ------- (u'child', u'china', u'trump', u'donald', u'would', u'agency')
# ------- (u'china', u'donald', u'would', u'trump', u'world', u'child')
# [(10.104511303471769, 7), (0.12612640172785661, 5)] The '5 disguises' used by human traffickers
# ------- (u'human', u'space', u'according', u'state', u'world', u'thicke')
# ------- (u'rocket', u'movie', u'space', u'state', u'president-elect', u'donald')
# [(4.9763240982280275, 6), (3.5417447371116886, 3)] Russia says regime controls eastern Aleppo, evacuations planned
# ------- (u'eastern', u'syrian', u'regime', u'aleppo', u'government', u'china')
# ------- (u'aleppo', u'government', u'regime', u'syrian', u'eastern', u'goodbye')
# [(3.3959425205978482, 8), (2.7848077135108276, 3)] The kids who put Aleppo's suffering on the map
# ------- (u'syrian', u'regime', u'aleppo', u'government', u'eastern', u'goodbye')
# ------- (u'aleppo', u'government', u'regime', u'syrian', u'eastern', u'goodbye')
# [(6.2617438437630817, 2), (2.325563384501864, 1)] Goodbye messages from Aleppo
# ------- (u'goodbye', u'aleppo', u'eastern', u'government', u'syrian', u'regime')
# ------- (u'government', u'aleppo', u'eastern', u'goodbye', u'regime', u'syrian')
# [(2.9141905352796273, 2), (1.5445576094339222, 3)] Opinion: Our inaction failed them
# ------- (u'goodbye', u'aleppo', u'eastern', u'government', u'syrian', u'regime')
# ------- (u'aleppo', u'government', u'regime', u'syrian', u'eastern', u'goodbye')
# [(2.8066837842988352, 8), (2.4988331314079182, 6)] Analysis: Assad will rule a wasteland
# ------- (u'syrian', u'regime', u'aleppo', u'government', u'eastern', u'goodbye')
# ------- (u'eastern', u'syrian', u'regime', u'aleppo', u'government', u'china')
# [(5.863112297900174, 3), (0.19082581086059414, 8)] What you need to know about Aleppo
# ------- (u'aleppo', u'government', u'regime', u'syrian', u'eastern', u'goodbye')
# ------- (u'syrian', u'regime', u'aleppo', u'government', u'eastern', u'goodbye')
# [(7.3762355270082134, 0), (0.0, 9)] UN drops Wonder Woman
# ------- (u'woman', u'aleppo', u'eastern', u'government', u'syrian', u'regime')
# ------- (u'china', u'trump', u'south', u'korea', u'woman', u'syrian')
# [(2.5780067732664063, 4), (0.012346602932906705, 7)] This could revolutionize breast cancer treatment
# ------- (u'south', u'korea', u'china', u'trump', u'woman', u'syrian')
# ------- (u'korea', u'south', u'aleppo', u'eastern', u'government', u'syrian')
# [(2.3889643099274842, 1), (7.4378998297790468e-07, 5)] Residents angry over government eviction orders
# ------- (u'government', u'aleppo', u'eastern', u'goodbye', u'regime', u'syrian')
# ------- (u'billion', u'china', u'trump', u'south', u'aleppo', u'goodbye')
# [(2.3724477682446374, 2), (9.9390452844273294e-07, 5)] Life after the Calais Jungle
# ------- (u'goodbye', u'aleppo', u'eastern', u'government', u'syrian', u'regime')
# ------- (u'billion', u'china', u'trump', u'south', u'aleppo', u'goodbye')
# [(0.89266832585518008, 9), (0.00012142489611521968, 6)] White House suggests Russian hacks helped Trump
# ------- (u'china', u'trump', u'south', u'korea', u'woman', u'syrian')
# ------- (u'eastern', u'syrian', u'regime', u'aleppo', u'government', u'china')
# [(2.3889643093813264, 1), (7.4403408269164693e-07, 5)] UK adopts international definition of anti-Semitism
# ------- (u'government', u'aleppo', u'eastern', u'goodbye', u'regime', u'syrian')
# ------- (u'billion', u'china', u'trump', u'south', u'aleppo', u'goodbye')
# [(0.8926683261510876, 9), (0.00012094563818095997, 6)] Trump gets real with Putin
# ------- (u'china', u'trump', u'south', u'korea', u'woman', u'syrian')
# ------- (u'eastern', u'syrian', u'regime', u'aleppo', u'government', u'china')
# [(7.9455215283034883, 9), (2.4360963383563927, 4)] Trump, don't play chicken with China
# ------- (u'china', u'trump', u'south', u'korea', u'woman', u'syrian')
# ------- (u'south', u'korea', u'china', u'trump', u'woman', u'syrian')
# [(6.4648610335780292, 7), (3.9618266053095672, 4)] How South Korea's politics could get even more confusing
# ------- (u'korea', u'south', u'aleppo', u'eastern', u'government', u'syrian')
# ------- (u'south', u'korea', u'china', u'trump', u'woman', u'syrian')
# [(5.3758586603028853, 5), (0.0, 9)] Italy's biggest bank to slash 14,000 jobs
# ------- (u'billion', u'china', u'trump', u'south', u'aleppo', u'goodbye')
# ------- (u'china', u'trump', u'south', u'korea', u'woman', u'syrian')
# [(2.6879293301514426, 5), (0.0, 9)] Galaxy count just increased 10x
# ------- (u'billion', u'china', u'trump', u'south', u'aleppo', u'goodbye')
# ------- (u'china', u'trump', u'south', u'korea', u'woman', u'syrian')
# [(4.6280202575131533, 1), (3.5214550962211263e-09, 9)] The Perfect Weapon: How Russian Cyberpower Invaded the U.S.
# ------- (u'russian', u'democratic', u'house', u'secretary', u'russia', u'state')
# ------- (u'russia', u'state', u'united', u'putin', u'vladimir', u'trump')
# [(8.0541227670645128, 1), (1.8925684307952406e-13, 9)] Democratic House Candidates Were Also Targets of Russian Hacking
# ------- (u'russian', u'democratic', u'house', u'secretary', u'russia', u'state')
# ------- (u'russia', u'state', u'united', u'putin', u'vladimir', u'trump')
# [(2.9250964762717886, 7), (2.3534715461870137, 9)] Spy Agency Consensus Grows That Russia Hacked D.N.C.
# ------- (u'state', u'secretary', u'executive', u'chief', u'trump\u2019s', u'exxon')
# ------- (u'russia', u'state', u'united', u'putin', u'vladimir', u'trump')
# [(9.2774009101581427, 9), (0.90124661779208948, 4)] The Interpreter: Russia and the U.S. Election: What We Know and Don’t Know
# ------- (u'russia', u'state', u'united', u'putin', u'vladimir', u'trump')
# ------- (u'president', u'afghanistan', u'executive', u'evacuation', u'chief', u'donald')
# [(8.9194648097446052, 0), (0.55420544176226694, 9)] Under Rex Tillerson, Exxon Mobil Forged Its Own Path Abroad
# ------- (u'tillerson', u'exxon', u'president', u'putin', u'vladimir', u'executive')
# ------- (u'russia', u'state', u'united', u'putin', u'vladimir', u'trump')
# [(6.5358388448990139, 0), (1.5791041852544259, 9)] Trump Lines Up Establishment Republicans to Vouch for Rex Tillerson
# ------- (u'tillerson', u'exxon', u'president', u'putin', u'vladimir', u'executive')
# ------- (u'russia', u'state', u'united', u'putin', u'vladimir', u'trump')
# [(8.6458046008689831, 7), (3.0419988315187898, 5)] Secretary of State Nominee Is a Flexible Pragmatist
# ------- (u'state', u'secretary', u'executive', u'chief', u'trump\u2019s', u'exxon')
# ------- (u'donald', u'president-elect', u'trump', u'trump\u2019s', u'kanye', u'briefing')
# [(8.0883688142370627, 5), (0.88817521874547378, 2)] From Kanye West to the Midwest, Donald Trump’s Presidential Reality Show Rolls On
# ------- (u'donald', u'president-elect', u'trump', u'trump\u2019s', u'kanye', u'briefing')
# ------- (u'kanye', u'visit', u'donald', u'trump', u'restaurant', u'manhattan')
# [(1.0682366430920653, 1), (0.0, 9)] John Kasich Signs One Abortion Bill in Ohio but Vetoes a More Restrictive Measure
# ------- (u'russian', u'democratic', u'house', u'secretary', u'russia', u'state')
# ------- (u'russia', u'state', u'united', u'putin', u'vladimir', u'trump')
# [(5.847191488602121, 3), (3.6457695899858793, 5)] Transition Briefing: Obama Names ‘Red Lines’ That Would Pull Him Back Into Political Fray
# ------- (u'trump', u'manhattan', u'tower', u'briefing', u'kanye', u'tillerson')
# ------- (u'donald', u'president-elect', u'trump', u'trump\u2019s', u'kanye', u'briefing')
# [(3.0506478976652254, 3), (2.0861067558618145, 7)] Rick Perry, Ex-Governor of Texas, Is Trump’s Pick as Energy Secretary
# ------- (u'trump', u'manhattan', u'tower', u'briefing', u'kanye', u'tillerson')
# ------- (u'state', u'secretary', u'executive', u'chief', u'trump\u2019s', u'exxon')
# [(6.4809895507234891, 3), (0.00069394855314091968, 4)] Trump Is Said to Offer Interior Job to Ryan Zinke, Montana Lawmaker
# ------- (u'trump', u'manhattan', u'tower', u'briefing', u'kanye', u'tillerson')
# ------- (u'president', u'afghanistan', u'executive', u'evacuation', u'chief', u'donald')
# [(2.4788970775946146, 5), (2.3003757268008207, 8)] Europe Edition: Aleppo, Rex Tillerson, Donald Trump: Your Wednesday Briefing
# ------- (u'donald', u'president-elect', u'trump', u'trump\u2019s', u'kanye', u'briefing')
# ------- (u'aleppo', u'evacuation', u'syria', u'united', u'briefing', u'tillerson')
# [(2.4791527783176002, 5), (2.3003667479032472, 8)] Rex Tillerson, Aleppo, Donald Trump: Your Evening Briefing
# ------- (u'donald', u'president-elect', u'trump', u'trump\u2019s', u'kanye', u'briefing')
# ------- (u'aleppo', u'evacuation', u'syria', u'united', u'briefing', u'tillerson')
# [(5.21556965407009, 8), (1.96056228549222, 9)] Battle Over Aleppo Is Over, Russia Says, as Evacuation Deal Reached
# ------- (u'aleppo', u'evacuation', u'syria', u'united', u'briefing', u'tillerson')
# ------- (u'russia', u'state', u'united', u'putin', u'vladimir', u'trump')
# [(6.2613769497171408, 8), (2.1677462080523435, 4)] Aleppo Evacuation Delayed as Rebels Blame Iran
# ------- (u'aleppo', u'evacuation', u'syria', u'united', u'briefing', u'tillerson')
# ------- (u'president', u'afghanistan', u'executive', u'evacuation', u'chief', u'donald')
# [(4.9014850961052137, 8), (0.34960969476805437, 9)] U.N. on Aleppo: ‘Massive Crimes May Be Underway’
# ------- (u'aleppo', u'evacuation', u'syria', u'united', u'briefing', u'tillerson')
# ------- (u'russia', u'state', u'united', u'putin', u'vladimir', u'trump')
# [(1.0636972052501164, 8), (1.8482069875238964e-242, 9)] 3 ISIS Terrorism Planners Killed in Syria Airstrike, Pentagon Says
# ------- (u'aleppo', u'evacuation', u'syria', u'united', u'briefing', u'tillerson')
# ------- (u'russia', u'state', u'united', u'putin', u'vladimir', u'trump')
# [(5.2651539677475663, 6), (1.2289871809834954, 2)] Top New York Restaurants of 2016
# ------- (u'restaurant', u'review', u'critic', u'visit', u'executive', u'calif.')
# ------- (u'kanye', u'visit', u'donald', u'trump', u'restaurant', u'manhattan')
# [(7.1488180319452583, 6), (3.0272192066915938e-05, 2)] Restaurant Review: Top New York Restaurants of 2016
# ------- (u'restaurant', u'review', u'critic', u'visit', u'executive', u'calif.')
# ------- (u'kanye', u'visit', u'donald', u'trump', u'restaurant', u'manhattan')
# [(3.755021973351242, 6), (6.6639892212880266e-06, 2)] Restaurant Review: The Top 10 New York Dishes of 2016
# ------- (u'restaurant', u'review', u'critic', u'visit', u'executive', u'calif.')
# ------- (u'kanye', u'visit', u'donald', u'trump', u'restaurant', u'manhattan')
# [(0.16396338121441012, 7), (1.4864060910002268e-07, 6)] Alan Thicke, Reassuring Father on ‘Growing Pains,’ Dies at 69
# ------- (u'state', u'secretary', u'executive', u'chief', u'trump\u2019s', u'exxon')
# ------- (u'restaurant', u'review', u'critic', u'visit', u'executive', u'calif.')
# [(1.2562238825822412, 6), (0.0, 9)] Review: ‘Rogue One’ Leaves ‘Star Wars’ Fans Wanting More and Less
# ------- (u'restaurant', u'review', u'critic', u'visit', u'executive', u'calif.')
# ------- (u'russia', u'state', u'united', u'putin', u'vladimir', u'trump')
# [(2.151226060100361, 6), (0.0, 9)] ‘Rogue One’ Reviews: Here’s What the Critics Say
# ------- (u'restaurant', u'review', u'critic', u'visit', u'executive', u'calif.')
# ------- (u'russia', u'state', u'united', u'putin', u'vladimir', u'trump')
# [(1.6588145649840471, 7), (0.32225392472528785, 9)] California Today
# ------- (u'state', u'secretary', u'executive', u'chief', u'trump\u2019s', u'exxon')
# ------- (u'russia', u'state', u'united', u'putin', u'vladimir', u'trump')
# [(8.2710371263250551, 4), (0.0268568653719722, 0)] Afghanistan Vice President Accused of Torturing Political Rival
# ------- (u'president', u'afghanistan', u'executive', u'evacuation', u'chief', u'donald')
# ------- (u'tillerson', u'exxon', u'president', u'putin', u'vladimir', u'executive')
# [(4.3558553747714512, 9), (7.7953398170312105e-08, 0)] Facing Athletes’ Boycott, Bobsled and Skeleton Event Is Moved From Russia
# ------- (u'russia', u'state', u'united', u'putin', u'vladimir', u'trump')
# ------- (u'tillerson', u'exxon', u'president', u'putin', u'vladimir', u'executive')
# [(0.12918157443443914, 8), (0.0, 9)] Mexico Grapples With a Surge in Violence
# ------- (u'aleppo', u'evacuation', u'syria', u'united', u'briefing', u'tillerson')
# ------- (u'russia', u'state', u'united', u'putin', u'vladimir', u'trump')
# [(0.16396338121441012, 7), (1.4864060910002268e-07, 6)] Reversing Course, E.P.A. Says Fracking Can Contaminate Drinking Water
# ------- (u'state', u'secretary', u'executive', u'chief', u'trump\u2019s', u'exxon')
# ------- (u'restaurant', u'review', u'critic', u'visit', u'executive', u'calif.')
# [(2.592952513655967, 3), (1.6674614919491482, 7)] Large Military Plane Over Manhattan Turns Heads Skyward
# ------- (u'trump', u'manhattan', u'tower', u'briefing', u'kanye', u'tillerson')
# ------- (u'state', u'secretary', u'executive', u'chief', u'trump\u2019s', u'exxon')
# [(0.89500217751812039, 6), (0.0, 9)] Pageant Silences Beauty Queen, a Critic of China, at U.S. Contest
# ------- (u'restaurant', u'review', u'critic', u'visit', u'executive', u'calif.')
# ------- (u'russia', u'state', u'united', u'putin', u'vladimir', u'trump')
# [(2.7128368447794826, 4), (1.9668405226301859, 7)] An N.F.L. Executive, Honoring His Lost Sister, Speaks Out About Anorexia
# ------- (u'president', u'afghanistan', u'executive', u'evacuation', u'chief', u'donald')
# ------- (u'state', u'secretary', u'executive', u'chief', u'trump\u2019s', u'exxon')
# [(1.9346467756850345, 4), (4.2720789517229875e-35, 6)] Kunduz Journal: Tending to the Living and the Dead in a Battle-Torn Afghan City
# ------- (u'president', u'afghanistan', u'executive', u'evacuation', u'chief', u'donald')
# ------- (u'restaurant', u'review', u'critic', u'visit', u'executive', u'calif.')
# [(0.54407821801188483, 9), (0.22005313076845592, 8)] U.N. Drops Wonder Woman as an Ambassador
# ------- (u'russia', u'state', u'united', u'putin', u'vladimir', u'trump')
# ------- (u'aleppo', u'evacuation', u'syria', u'united', u'briefing', u'tillerson')
# [(7.7411863204604767, 2), (0.66364242924135364, 5)] Kanye West Visits Donald Trump
# ------- (u'kanye', u'visit', u'donald', u'trump', u'restaurant', u'manhattan')
# ------- (u'donald', u'president-elect', u'trump', u'trump\u2019s', u'kanye', u'briefing')
# [(1.569734221748857, 7), (0.87962451290509636, 9)] Christians in U.S. Are Less Educated Than Religious Minorities, Report Says
# ------- (u'state', u'secretary', u'executive', u'chief', u'trump\u2019s', u'exxon')
# ------- (u'russia', u'state', u'united', u'putin', u'vladimir', u'trump')
# [(1.2633337100900559, 2), (1.0419115445797245, 3)] The Neediest Cases: Back on Her Feet at 85, Thanks to a Chair
# ------- (u'kanye', u'visit', u'donald', u'trump', u'restaurant', u'manhattan')
# ------- (u'trump', u'manhattan', u'tower', u'briefing', u'kanye', u'tillerson')
# [(8.2756772239758529, 5), (0.98070590330443019, 0)] Secretary of State Nominee Is a Flexible Pragmatist
# ------- (u'secretary', u'state', u'tillerson', u'exxon', u'president-elect', u'trump\u2019s')
# ------- (u'trump\u2019s', u'donald', u'senator', u'secretary', u'president-elect', u'leader')
# [(1.1985625117507306, 2), (7.2249292324467573e-45, 4)] Wells Fargo’s ‘Living Will’ Plan Is Rejected Again by Regulators
# ------- (u'well', u'fargo', u'lawsuit', u'policy', u'thomas', u'potential')
# ------- (u'australia', u'wright', u'company', u'former', u'calif.', u'lawsuit')
# [(4.5495027667746317, 2), (0.51008436354654441, 8)] Big Banks Fight to Block Crisis-Era Lawsuits From Continuing
# ------- (u'well', u'fargo', u'lawsuit', u'policy', u'thomas', u'potential')
# ------- (u'talk', u'another', u'company', u'potential', u'ended', u'wright')
# [(8.6155478145014719, 3), (0.0, 9)] Japan, Looking for Money, Is Poised to Legalize Casino Gambling
# ------- (u'gambling', u'would', u'another', u'billion', u'leader', u'president-elect')
# ------- (u'billion', u'raise', u'company', u'leader', u'russia', u'president-elect')
# [(2.2766893986989394, 1), (1.7013921419786142, 9)] A Trump Economic Boom? The Fed May Stand in the Way
# ------- (u'trump', u'leader', u'would', u'economic', u'donald', u'company')
# ------- (u'billion', u'raise', u'company', u'leader', u'russia', u'president-elect')
# [(1.8174184470829995, 8), (0.42456981881695011, 1)] Cars Talking to One Another? They Could Under Proposed Safety Rules
# ------- (u'talk', u'another', u'company', u'potential', u'ended', u'wright')
# ------- (u'trump', u'leader', u'would', u'economic', u'donald', u'company')
# [(0.73759027773230956, 8), (0.463156529463151, 7)] Google Parent Company Spins Off Self-Driving Car Business
# ------- (u'talk', u'another', u'company', u'potential', u'ended', u'wright')
# ------- (u'exxon', u'russia', u'tillerson', u'company', u'billion', u'trump')
# [(1.0613146385906618, 2), (0.074130638406485969, 5)] Fox Faces New Lawsuit Claiming Harassment by Roger Ailes
# ------- (u'well', u'fargo', u'lawsuit', u'policy', u'thomas', u'potential')
# ------- (u'secretary', u'state', u'tillerson', u'exxon', u'president-elect', u'trump\u2019s')
# [(5.8029169481405498, 7), (1.3118398958427742, 1)] Trump Lines Up Establishment Republicans to Vouch for Rex Tillerson
# ------- (u'exxon', u'russia', u'tillerson', u'company', u'billion', u'trump')
# ------- (u'trump', u'leader', u'would', u'economic', u'donald', u'company')
# [(8.1938677313014594, 7), (1.3007954002840141, 9)] Rex Tillerson’s Company, Exxon, Has Billions at Stake Over Sanctions on Russia
# ------- (u'exxon', u'russia', u'tillerson', u'company', u'billion', u'trump')
# ------- (u'billion', u'raise', u'company', u'leader', u'russia', u'president-elect')
# [(2.1192156179933677, 9), (0.050891719802788865, 1)] Legal Financing Rivals to Combine in $160 Million Deal
# ------- (u'billion', u'raise', u'company', u'leader', u'russia', u'president-elect')
# ------- (u'trump', u'leader', u'would', u'economic', u'donald', u'company')
# [(7.3327988072763723, 4), (0.0, 9)] K.K.R.-Linked Group Bids for Tatts of Australia, Imperiling Tabcorp Deal
# ------- (u'australia', u'wright', u'company', u'former', u'calif.', u'lawsuit')
# ------- (u'billion', u'raise', u'company', u'leader', u'russia', u'president-elect')
# [(0.062388949496104462, 8), (0.0006045541298483095, 9)] An (Edible) Solution to Extend Produce’s Shelf Life
# ------- (u'talk', u'another', u'company', u'potential', u'ended', u'wright')
# ------- (u'billion', u'raise', u'company', u'leader', u'russia', u'president-elect')
# [(1.4668707670082379, 1), (1.4276231354114892, 0)] Rick Perry, Ex-Governor of Texas, Is Trump’s Pick as Energy Secretary
# ------- (u'trump', u'leader', u'would', u'economic', u'donald', u'company')
# ------- (u'trump\u2019s', u'donald', u'senator', u'secretary', u'president-elect', u'leader')
# [(9.0979681535644357, 1), (1.762168284807841, 6)] When Trump Meets Tech Leaders, Jobs Will Be on the Agenda
# ------- (u'trump', u'leader', u'would', u'economic', u'donald', u'company')
# ------- (u'rally', u'senator', u'ended', u'policy', u'state', u'billion')
# [(8.0959738744496441, 2), (3.9684426916375192e-09, 4)] Prudential Suspends Sales of Its Life Policies by Wells Fargo
# ------- (u'well', u'fargo', u'lawsuit', u'policy', u'thomas', u'potential')
# ------- (u'australia', u'wright', u'company', u'former', u'calif.', u'lawsuit')
# [(8.2792266555870562, 8), (0.0031073541097978471, 6)] Actelion Says It Continues Deal Talks as J&J Drops Out
# ------- (u'talk', u'another', u'company', u'potential', u'ended', u'wright')
# ------- (u'rally', u'senator', u'ended', u'policy', u'state', u'billion')
# [(6.6787836464553934, 6), (0.22967128953860041, 8)] Wall St. Adds to Record Rally, Dow Approaches 20,000
# ------- (u'rally', u'senator', u'ended', u'policy', u'state', u'billion')
# ------- (u'talk', u'another', u'company', u'potential', u'ended', u'wright')
# [(8.046243658186123, 9), (0.0030557105428927513, 6)] UniCredit to Cut 14,000 Jobs and Raise Nearly $14 Billion in Overhaul
# ------- (u'billion', u'raise', u'company', u'leader', u'russia', u'president-elect')
# ------- (u'rally', u'senator', u'ended', u'policy', u'state', u'billion')
# [(0.062388949496104462, 8), (0.00060455412984830917, 9)] Reversing Course, E.P.A. Says Fracking Can Contaminate Drinking Water
# ------- (u'talk', u'another', u'company', u'potential', u'ended', u'wright')
# ------- (u'billion', u'raise', u'company', u'leader', u'russia', u'president-elect')
# [(4.815991476530165, 1), (2.0001002726544499, 0)] Economic Scene: Where Were Trump’s Votes? Where the Jobs Weren’t
# ------- (u'trump', u'leader', u'would', u'economic', u'donald', u'company')
# ------- (u'trump\u2019s', u'donald', u'senator', u'secretary', u'president-elect', u'leader')
# [(5.5954795067500305, 6), (0.97987428657693276, 0)] DealBook: Elizabeth Warren Condemns the Wrong Man
# ------- (u'rally', u'senator', u'ended', u'policy', u'state', u'billion')
# ------- (u'trump\u2019s', u'donald', u'senator', u'secretary', u'president-elect', u'leader')
# [(0.66532634547281977, 8), (0.21807275205644655, 2)] Deal Professor: A Potential Hitch in Zuckerberg’s Stock Plan for Facebook
# ------- (u'talk', u'another', u'company', u'potential', u'ended', u'wright')
# ------- (u'well', u'fargo', u'lawsuit', u'policy', u'thomas', u'potential')
# [(0.53820078692453188, 1), (0.0027339221170064529, 6)] Itineraries: Gifts That Santa, the World Traveler, Would Love
# ------- (u'trump', u'leader', u'would', u'economic', u'donald', u'company')
# ------- (u'rally', u'senator', u'ended', u'policy', u'state', u'billion')
# [(0.14978338894160856, 8), (0.084661008724283643, 0)] Square Feet: Pitching In to Preserve Aviation History
# ------- (u'talk', u'another', u'company', u'potential', u'ended', u'wright')
# ------- (u'trump\u2019s', u'donald', u'senator', u'secretary', u'president-elect', u'leader')
# [(0.98243601430839733, 8), (0.4999124188779398, 7)] Square Feet: Sites for Aviation Buffs
# ------- (u'talk', u'another', u'company', u'potential', u'ended', u'wright')
# ------- (u'exxon', u'russia', u'tillerson', u'company', u'billion', u'trump')
# [(1.0764132526697476, 1), (0.0054688428341040608, 6)] New Approach to Corporate Tax Law Has House G.O.P. Support
# ------- (u'trump', u'leader', u'would', u'economic', u'donald', u'company')
# ------- (u'rally', u'senator', u'ended', u'policy', u'state', u'billion')
# [(8.8455625193670251, 0), (0.11466098702527949, 5)] Donald Trump’s Wealthy Cabinet Picks to Undergo Financial Scrutiny He Didn’t Face
# ------- (u'trump\u2019s', u'donald', u'senator', u'secretary', u'president-elect', u'leader')
# ------- (u'secretary', u'state', u'tillerson', u'exxon', u'president-elect', u'trump\u2019s')
# [(1.0846847530027066, 6), (0.92934210400327077, 2)] Year of Upheaval for Restaurants That Ended Tipping
# ------- (u'rally', u'senator', u'ended', u'policy', u'state', u'billion')
# ------- (u'well', u'fargo', u'lawsuit', u'policy', u'thomas', u'potential')
# [(1.1318851152752343, 2), (1.9241998845398876e-260, 4)] Thomas C. Schelling, Master Theorist of Nuclear Strategy, Dies at 95
# ------- (u'well', u'fargo', u'lawsuit', u'policy', u'thomas', u'potential')
# ------- (u'australia', u'wright', u'company', u'former', u'calif.', u'lawsuit')
# [(2.5342830151346232, 2), (1.652406436391269e-68, 7)] Kunduz Journal: Tending to the Living and the Dead in a Battle-Torn Afghan City
# ------- (u'afghanistan', u'president', u'syria', u'aleppo', u'britain', u'op-ed')
# ------- (u'critic', u'russia', u'president', u'afghanistan', u'china', u'aleppo')
# [(7.1726253924977348, 2), (2.0786538608258733, 0)] Afghanistan Vice President Accused of Torturing Political Rival
# ------- (u'afghanistan', u'president', u'syria', u'aleppo', u'britain', u'op-ed')
# ------- (u'president', u'op-ed', u'contributor', u'taiwan', u'china', u'united')
# [(6.4112576820090537, 6), (0.69660336816294766, 7)] Battle Over Aleppo Is Over, Russia Says, as Evacuation Deal Reached
# ------- (u'aleppo', u'russia', u'syria', u'president', u'op-ed', u'contributor')
# ------- (u'critic', u'russia', u'president', u'afghanistan', u'china', u'aleppo')
# [(9.36632165735519, 3), (0.23769090023171827, 9)] 3 ISIS Terrorism Planners Killed in Syria Airstrike, Pentagon Says
# ------- (u'killed', u'syria', u'united', u'headquarters', u'china', u'taiwan')
# ------- (u'contributor', u'op-ed', u'syria', u'aleppo', u'president', u'killed')
# [(1.2911027401869151, 8), (3.2859469774839072e-07, 3)] The Perfect Weapon: How Russian Cyberpower Invaded the U.S.
# ------- (u'protest', u'headquarters', u'united', u'year', u'britain', u'china')
# ------- (u'killed', u'syria', u'united', u'headquarters', u'china', u'taiwan')
# [(3.4332524402328665e-05, 8), (1.932737200312445e-06, 2)] Child Sexual Abuse Scandal Rocks U.K. Soccer
# ------- (u'protest', u'headquarters', u'united', u'year', u'britain', u'china')
# ------- (u'afghanistan', u'president', u'syria', u'aleppo', u'britain', u'op-ed')
# [(2.5249289737883176, 8), (3.0990427280166653e-35, 4)] Protests Erupt in Poland Over New Law on Public Gatherings
# ------- (u'protest', u'headquarters', u'united', u'year', u'britain', u'china')
# ------- (u'year', u'china', u'protest', u'headquarters', u'president', u'taiwan')
# [(2.2372298237721413, 0), (1.9238863292116846, 7)] Under Rex Tillerson, Exxon Mobil Forged Its Own Path Abroad
# ------- (u'president', u'op-ed', u'contributor', u'taiwan', u'china', u'united')
# ------- (u'critic', u'russia', u'president', u'afghanistan', u'china', u'aleppo')
# [(6.3302969907721289, 8), (3.1089422586795461, 4)] Protests Erupt Across Brazil as Senate Approves Austerity Measure
# ------- (u'protest', u'headquarters', u'united', u'year', u'britain', u'china')
# ------- (u'year', u'china', u'protest', u'headquarters', u'president', u'taiwan')
# [(1.1988722430669254, 1), (4.4719103799193527e-07, 3)] No Change in U.S. Commitment to Asia-Pacific Under Trump, Admiral Says
# ------- (u'taiwan', u'united', u'president', u'china', u'headquarters', u'year')
# ------- (u'killed', u'syria', u'united', u'headquarters', u'china', u'taiwan')
# [(9.6737677592070384, 1), (1.4225501627608541, 5)] Sinosphere: For Taiwan, a Dilemma Over Identity, Economy and China
# ------- (u'taiwan', u'united', u'president', u'china', u'headquarters', u'year')
# ------- (u'china', u'critic', u'taiwan', u'united', u'year', u'president')
# [(6.708366615313702, 5), (0.90070516307817439, 7)] Pageant Silences Beauty Queen, a Critic of China, at U.S. Contest
# ------- (u'china', u'critic', u'taiwan', u'united', u'year', u'president')
# ------- (u'critic', u'russia', u'president', u'afghanistan', u'china', u'aleppo')
# [(1.4369956314434882, 8), (1.1619972331871529, 1)] U.N. Drops Wonder Woman as an Ambassador
# ------- (u'protest', u'headquarters', u'united', u'year', u'britain', u'china')
# ------- (u'taiwan', u'united', u'president', u'china', u'headquarters', u'year')
# [(6.8665048804657331e-05, 8), (3.8654744006248901e-06, 2)] With ‘Trousergate,’ Politics and Pants Collide in Britain
# ------- (u'protest', u'headquarters', u'united', u'year', u'britain', u'china')
# ------- (u'afghanistan', u'president', u'syria', u'aleppo', u'britain', u'op-ed')
# [(7.9101333090567705, 7), (0.15315620947526556, 5)] Aleksei Navalny, Putin Critic, Says He’ll Run for President of Russia
# ------- (u'critic', u'russia', u'president', u'afghanistan', u'china', u'aleppo')
# ------- (u'china', u'critic', u'taiwan', u'united', u'year', u'president')
# [(3.3454850852757176, 4), (0.00021103471846496132, 8)] Tunisian Captain in Deadly Migrant Shipwreck Jailed for 18 Years
# ------- (u'year', u'china', u'protest', u'headquarters', u'president', u'taiwan')
# ------- (u'protest', u'headquarters', u'united', u'year', u'britain', u'china')
# [(1.1988722430669254, 1), (4.4719103799193527e-07, 3)] Christians in U.S. Are Less Educated Than Religious Minorities, Report Says
# ------- (u'taiwan', u'united', u'president', u'china', u'headquarters', u'year')
# ------- (u'killed', u'syria', u'united', u'headquarters', u'china', u'taiwan')
# [(2.5249289737883176, 8), (5.8582678756811e-36, 4)] Governor of Jakarta Issues Tearful Denial as Blasphemy Trial Opens in Indonesia
# ------- (u'protest', u'headquarters', u'united', u'year', u'britain', u'china')
# ------- (u'year', u'china', u'protest', u'headquarters', u'president', u'taiwan')
# [(2.507051437828971, 3), (3.2694790573545094e-17, 9)] Mexico Grapples With a Surge in Violence
# ------- (u'killed', u'syria', u'united', u'headquarters', u'china', u'taiwan')
# ------- (u'contributor', u'op-ed', u'syria', u'aleppo', u'president', u'killed')
# [(3.3546811582032614, 4), (2.9114410651859637, 5)] Only a Rumbling Volcano Could Make North Korea and the West Play Nice
# ------- (u'year', u'china', u'protest', u'headquarters', u'president', u'taiwan')
# ------- (u'china', u'critic', u'taiwan', u'united', u'year', u'president')
# [(3.7723256551334119, 9), (3.4716241198650009, 0)] Op-Ed Contributor: Colombia Needs Help to Make Peace Last
# ------- (u'contributor', u'op-ed', u'syria', u'aleppo', u'president', u'killed')
# ------- (u'president', u'op-ed', u'contributor', u'taiwan', u'china', u'united')
# [(4.6305580447047818, 9), (0.21670807747397261, 0)] Op-Ed Contributor: To Be or Not to Be a Dictator
# ------- (u'contributor', u'op-ed', u'syria', u'aleppo', u'president', u'killed')
# ------- (u'president', u'op-ed', u'contributor', u'taiwan', u'china', u'united')
# [(5.8956321063644781, 6), (4.3595139039949009, 9)] Op-Ed Contributor: What Comes After Aleppo Falls?
# ------- (u'aleppo', u'russia', u'syria', u'president', u'op-ed', u'contributor')
# ------- (u'contributor', u'op-ed', u'syria', u'aleppo', u'president', u'killed')
# [(3.3454767599064579, 4), (0.00036330390458328674, 8)] Where Even Nightmares Are Classified: Psychiatric Care at Guantánamo
# ------- (u'year', u'china', u'protest', u'headquarters', u'president', u'taiwan')
# ------- (u'protest', u'headquarters', u'united', u'year', u'britain', u'china')
# [(3.3454769260233808, 4), (0.00036027069873387208, 8)] Turkish Dam Project Threatens to Submerge Thousands of Years of History
# ------- (u'year', u'china', u'protest', u'headquarters', u'president', u'taiwan')
# ------- (u'protest', u'headquarters', u'united', u'year', u'britain', u'china')

# %% [markdown]
# ## Aufgaben
#
# 1. Analysieren Sie die berechneten Topics indem Sie sich überlegen ob die gefundenen 6 Wörter pro Topic wirklich Themen beschreiben.
# 2. Verändern Sie die Parameter der NNMF (Anzahl der Topics $m$, Anzahl der Iterationen). Bei welcher Einstellung der Parameter erhalten Sie das für sie sinnvollste Resultat (sinnvolle Topics)?
# 3. Wie kann die _getwords()_ Methode verbessert werden, so dass noch bedeutsamere Topics gefunden werden?

# %% [markdown]
# ### Aufgabe 1
# Für eine grobe Einordnung des Artikels reichen 6 Wörter aus. Vor allem bei Artikeln, bei denen ein sehr hohes Gewicht für das jeweilige Topic gefunden wurde (3 oder mehr), beschreiben die Wörter das Thema ziemlich akurat.
#
# Topics, die für einen Artikel weniger gut passen, sind dagegen oft nicht aussagekräftig genug um wirklich genau zu wissen worum es geht.
#
# Es kommt hin und wieder vor, dass Topics sehr ähnlich sind. Beispiel vom 14.12.2016:
#
# ```
# [(4.4099527642498799, 5), (1.4233473037636633e-06, 7)] Aleppo evacuation may be delayed until Thursday
# ------- (u'aleppo', u'trump', u'energy', u'department', u'president-elect', u'donald')
# ------- (u'thicke', u'trump', u'energy', u'department', u'washington', u'president-elect')
# ```
#
# In diesen Fällen wäre eine größere Anzahl an Wörtern wünschenswert um Unterschiede zu erkennen. Auf den ersten Blick sehen die Topics nämlich sehr ähnlich aus, jedoch hat das erste ein deutlich höheres Gewicht.
#
#
# ### Aufgabe 2
#
# Zu dem Zeitpunkt des Schreibens, wurde bei maximal 38 Iterationen für jede Matrix eine Faktorisierung gefunden. In diesem Fall ist ein höhrer Wert unnötig, da dieser keine Auswirkung auf das Ergebnis mehr hat. Allerdings kann es natürlich sein, dass bei anderen Dokumenten mehr Iterationen nötig sind. Deshalb haben wir einen Wert von 50 gewählt.
#
# Die Anzahl der Topics m haben wir auf 10 gesetzt, da die Breite der Artikel-Wort Matrix für die meisten Artikel nach dem Preprocessing relativ gering ist. Da c < m gewählt werden muss ist dies zwangsweise nötig.
#
# Eine hohe Anzahl von Topics erhöht außerdem im Durchschnitt auch die Gewichte für die einzelnen Artikel. D.h. die gefundenen Topics stimmen besser mit den individuellen Artikeln überein. Eine zu hohe Anzahl an Topics ist problematisch, da sonst für jeden Artikel ein einzelnes Topic gefunden wird.
#
#
# ### Aufgabe 3
#
# Bei der Ausgabe der Topics war zunächst auffällig, dass trotz der Entfernung der Stopwörter, bestimmte Wörter wie z.B.
# 'reuters' (Name der Nachrichtenagentur), Wörter die Zeiten bezeichnen e.g. 'today', 'tomorrow' und andere aussageschwache Wörter, immernoch in einem Großteil der Topics vorkamen. Diese haben wir manuell entfernt. Dazu kam, dass Topics oft ein Wort und zusätzlich den Plural des Wortes beinhaltet haben. Das Problem lässt sich mit einer Lematisierung lösen. Anstelle eines simplen Regex, benutzen wir nun einen Tokenizer.
#
# Die neue Version kann im oberen Abschnitt unter dem Name `getwords` gefunden werden. Die Funktion die wir zuvor benutzt haben heißt `getwordsold`.
