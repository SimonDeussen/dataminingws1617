# %% [markdown]
# # Topic Extraction in Newsfeeds
# * Autor: Prof. Dr. Johannes Maucher
# * Datum: 17.11.2015
#
# [Übersicht Ipython Notebooks im Data Mining Praktikum](Data Mining Praktikum.html)
#
# # Einführung
# ## Lernziele:
#
# In diesem Versuch sollen Kenntnisse in folgenden Themen vermittelt werden:
#
# * __RSS Feeds:__ Struktur von RSS Feeds analysieren und parsen mit dem _Universal Feed Parser_.
# * __Dokument Analyse:__ Die Häufigkeit aller Worte in einem Dokument (Inhalt des RSS Feeds) zählen und in einem Array verwalten.
# * __Merkmalsextraktion:__ Bestimmung von Merkmalen (hier auch: __Topics__) (Allgemein spricht man von Merkmalen. Im Fall, dass die NNMF auf Dokumente angewandt wird, werden die Merkmale auch mit __Topics__ oder __Themen__ bezeichnet) mit der \emph{Non Negative Matrix Factorization}.
# * __Zuordnung__: Wie setzen sich die Topics aus den Wörtern zusammen? Wie stark sind die gefundenen Topics in den Artikeln vertreten?
# * __Dokument Clustering:__ Mit der NNMF kann auch ein Clustering realisiert werden. Jeder Topic repräsentiert ein Cluster. Jedes Dokument wird dem Cluster zugeordnet, dessen Topic am stärksten in ihm vertreten ist.
#
# Sämtliche Verfahren und Algorithmen werden in Python implementiert.
#
# ## Theorie zur Vorbereitung
#
# Stellen Sie sich vor Sie möchten in eine eigene Webseite die RSS Feeds einer Menge von Nachrichtenservern einbinden. Da die unterschiedlichen Server wahrscheinlich Artikel zu den gleichen Themen anbieten, werden die Inhalte einiger Artikel ähnlich sein. Mit der __Nicht Negativen Matrixfaktorisierung (NNMF)__ kann für eine große Menge von Dokumenten eine Menge von Themen (Topics) ermittelt werden, auf die sich die Dokumente beziehen. Damit ist es u.a. möglich
# * die Dokumente thematisch zu ordnen
# * zu jedem Thema nur ein Dokument anzuzeigen
#
# ### Ähnlichkeiten bestimmen und relevante Merkmale extrahieren
#
# Eine Sammlung von Dokumenten - in diesem Versuch die Menge aller Nachrichten der angegebenen Feeds - kann in einer Artikel/Wort-Matrix repräsentiert werden. Jede Zeile dieser Matrix gehört zu einem Dokument. Für jedes Wort, das mindestens in einem der Dokumente vorkommt, ist eine Spalte vorgesehen. Das Matrixelement in Zeile $i$, Spalte $j$ beschreibt wie häufig das Wort in Spalte $j$ im zur Zeile $i$ gehörenden Dokument vorkommt.
#
# Unter der Annahme, dass Artikel umso ähnlicher sind, je mehr Worte in diesen gemeinsam vorkommen, kann auf der Grundlage dieser Matrix die Ähnlichkeit zwischen den Artikeln berechnet werden. Hierzu könnte die Matrix z.B. einfach einem _Hierarchischen Clustering_ übergeben werden. Das hierarchische Clustering weist jedoch im Fall einer großen Menge von zu vergleichenden Objekten zwei wesentliche Nachteile auf: Erstens ist die wiederholte Berechnung der Distanzen zwischen allen Artikeln/Clustern extrem rechenaufwendig, zweitens ist die Darstellung einer großen Anzahl von Objekten im Dendrogramm nicht mehr übersichtlich.
#
# Für das Auffinden von Assoziationen zwischen Dokumenten hat sich in den letzten Jahren die Methode der __Nicht-Negativen Matrix Faktorisierung (NNMF)__ etabliert. Mit dieser Methode kann eine Menge von wesentlichen Merkmalen berechnet werden, anhand derer sich die Dokumente clustern lassen, d.h. Dokumente des gleichen Clusters repräsentieren das gleiche Merkmal (Thema). Ein solches Merkmal wird durch eine Menge von Worten beschrieben, z.B. $\{$ _Paris, terror, IS_ $\}$  oder $\{$_refugee, syria, border_ $\}$. Neben der Merkmalsextraktion stellt die relativ geringe Komplexität einen weiteren Vorteil der NNMF dar. Durch die Darstellung der Artikel/Wort-Matrix als Produkt von 2 Faktormatrizen müssen deutlich weniger Einträge gespeichert werden.
#
# ### Nicht Negative Matrixfaktorisierung: Die Idee
#
# Die Artikel/Wort-Matrix wird im Folgenden mit $A$ bezeichnet. Sie besitzt $r$ Zeilen und $c$ Spalten, wobei $r$ die Anzahl der Artikel und $c$ die Anzahl der relevanten Worte in der Menge aller Artikel ist. Durch Multiplikation der Matrix $A$ mit dem Vektor $v$ (_wordvec_: Vektor der alle relevanten Worte enthält) werden die Worte den Artikeln $a$ (_articletitles_: Vektor der alle Artikeltitel enthält) zugeordnet:
#
# $$
# a=A*v.
# $$
#
# Die Idee der NNMF besteht darin die Matrix $A$ als Produkt zweier Matrizen $W$ und $H$ darzustellen,
#
# $$
# A=W*H
# $$
#
# wobei alle Elemente in $W$ und $H$ größer oder gleich Null sein müssen. Die Matrixmultiplikation erfordert, dass die Anzahl der Zeilen $m$ in $H$ gleich der Anzahl der Spalten in $W$ sein muss.
# Durch die Faktorisierung der Matrix $A$ wird die Zuordnung der Wörter des Wortvektors $v$  zu den Artikeln des Vektors $a$ in zwei Stufen zerlegt.
#
# $$
# f = H*v
# $$
# $$
# a = W*f
# $$
#
# In der ersten Stufe werden durch die Multiplikation von $v$ mit der Matrix $H$ die Wörter einem sogenannten Merkmalsvektor $f$ mit $m$ Elementen zugewiesen. In der zweiten Stufe werden durch die Multiplikation des Merkmalsvektor $f$ mit der Matrix $W$ die einzelnen Merkmale den Artikeln in $a$ zugeordnet. Die Matrix $H$ definiert also aus welchen Wörtern die Merkmale gebildet werden. Sie wird deshalb __Merkmalsmatrix__ genannt. Die Matrix $W$ hingegen beschreibt mit welchem Gewicht die einzelnen Merkmale in den verschiedenen Artikeln auftreten. Sie wird deshalb __Gewichtungsmatrix__ genannt.
#
# Daraus folgt: Wenn eine Faktorisierung der Matrix $A$ gefunden wird, dann werden damit auch relevante Merkmale, also die Themen, definiert, hinsichtlich derer die Artikel effizient kategorisiert werden. Durch die Matrixfaktorisierung wird eine __Merkmalsextraktion__ realisiert.
#
# ### Berechnung der Matrixfaktoren
#
# Für die Berechnung der Faktoren wurde in [Lee, Algortihms for Non-negative Matrix Factorisation](http://papers.nips.cc/paper/1861-algorithms-for-non-negative-matrix-factorization.pdf) eine iterative Methode vorgestellt, die derzeit wohl am häufigsten angewandt wird und auch in dieser Übung implementiert werden soll. Der Algorithmus besteht aus folgenden Schritten:
# * Gebe die zu faktorisierende Matrix $A$ ein. $r$ sei die Anzahl der Zeilen und $c$ die Anzahl der Spalten von $A$.
# * Wähle die Anzahl $m$ der Merkmale, mit $m<c$. _Tipp:_ Für $m$ sollte zunächst ein Wert im Bereich $15$ bis $30$ gewählt werden.
# * Lege eine $m \times c$ Matrix $H$ an mit initial zufälligen Elementen (Anwendung der numpy Funktion _random.random()_)
# * Lege eine $r \times m$ Matrix $W$ an mit initial zufälligen Elementen (Anwendung der numpy Funktion _random.random()_)
# * Wiederhole bis maximale Anzahl der Iteration erreicht oder Kosten $k$ unter vordefinierter Schwelle:
#
# 	* Berechne aktuelles Produkt $B=W*H$ und bereche die Kostenfunktion
# 		$$
# 			k=\left\| A - B \right\|^2 = \sum\limits_{i,j} \left(A_{i,j} - B_{i,j}\right)^2
# 		$$
# 	* Anpassung der Matrix $H$ durch folgende Neuberechnung der Matrixelemente
#
# 		$$
# 		H_{i,j} := H_{i,j} \frac{(W^T*A)_{i,j}}{(W^T*W*H)_{i,j}}
# 		$$
#
# 	* __Nach__ der Anpassung der Matrix $H$: Anpassung der Matrix $W$ durch folgende Neuberechnung der Matrixelemente
#
# 		$$
# 		W_{l,i} := W_{l,i} \frac{(A*H^T)_{l,i}}{(W*H*H^T)_{l,i}}
# 		$$
#
# In [Lee, Algortihms for Non-negative Matrix Factorisation](http://papers.nips.cc/paper/1861-algorithms-for-non-negative-matrix-factorization.pdf) ist bewiesen, dass durch die o.g. Anpassungsroutinen die Kosten $k$ monoton abnehmen und in einem Minimum konvergieren. Der Algorithmus ist jedoch nicht optimal weil das gefundene Minimum ein lokales Minimum sein kann.

# %% [markdown]
#  ## Vor dem Versuch zu klärende Fragen
#
#  * Was versteht man unter Artikel/Wort-Matrix? Wie wird diese im aktuellen Versuch gebildet?

# %% [markdown]
# Eine Artikel/Wort Matrix besteht aus r Zeilen, die für die Artikel stehen und c Spalten die für alle Wörter in den Artikeln stehen. Die Werte innerhalb einer Zeile stehen für die Häufigkeit der jeweiligen Worte.

# %% [markdown]
# * Wie multipliziert man die Matrix
#     $$
#     A= \left( \begin{array}{cccc}
# a_{00} & a_{01} & a_{02} & a_{03} \\
# a_{10} & a_{11} & a_{12} & a_{13} \\
# a_{20} & a_{21} & a_{22} & a_{23}
# \end{array} \right)
#     $$
#     mit dem Vektor
#     $$
#     v=\left( \begin{array}{c}
# v_{0} \\
# v_{1} \\
# v_{2} \\
# v_{3}
# \end{array} \right)
#     $$

# %% [markdown]
# a = A &ast; v
#
#
# a = (a00&ast;v0 + a01&ast;v1 + a02&ast;v2 + a03&ast;v3)
#     (a10&ast;v0 + a11&ast;v1 + a12&ast;v2 + a13&ast;v3)
#     (a20&ast;v0 + a21&ast;v1 + a22&ast;v2 + a23&ast;v3)

# %% [markdown]
# * Was versteht man im Kontext der NNMF unter
#     * Merkmalsmatrix
#     * Gewichtsmatrix

# %% [markdown]
# Die Merkmalsmatrix ist eine Merkmal x Wort Matrix, die für ein Merkmal die Wörter festlegt, die dieses Mermal ausmachen.
# Die Gewichtsmatrix ist eine Artikel x Merkmals Matrix, die für jeden Artikel die Gewichtung der einzelnen Mermale bestimmt, d.h. wie stark ein Merkmal in dem Artikel vertreten ist

# %% [markdown]
# * Wie definieren die Zeilen der Merkmalsmatrix die einzelnen Merkmale (Topics)?
# * Was definieren die Zeilen der Gewichtungsmatrix?

# %% [markdown]
# Eine Zeile der Mermalsmatrix steht für ein gefundenes Merkmal.
# Eine Zeile steht der Gewichtungsmatrix steht für einen bestimmten Artikel.

# %% [markdown]
# * Wie werden in Numpy zwei Arrays (Typ numpy.array)
# 	* im Sinne der Matrixmultiplikation miteinander multipliziert?
# 	* elementweise multipliziert?
# * Wie wird die Transponierte eines Numpy-Arrays berechnet?

# %%
import numpy as np

a = np.matrix([[1, 1], 
               [1, 1]])

b = np.matrix([[0, 1], 
               [2, 0]])

# Matrixmultiplikation
print a * b

# Elementweise Multiplikation
print np.multiply(a, b)

# Matrix transponieren
print b.transpose()
# Out:
# [[2 1]
#  [2 1]]
# [[0 1]
#  [2 0]]
# [[0 2]
#  [1 0]]

# %% [markdown]
# # Versuchsdurchführung
# Die in diesem Versuch einzubindenden Feeds sind in der unten stehenden Liste _feedlist_ definiert. Die aus dem vorigen Vesuch bereits bekannte Funktion _stripHTML()_ ist ebenfalls gegeben:

# %%
import feedparser

feedlist=['http://feeds.reuters.com/reuters/topNews',
          'http://feeds.reuters.com/reuters/businessNews',
          'http://feeds.reuters.com/reuters/worldNews',
          'http://feeds2.feedburner.com/time/world',
          'http://feeds2.feedburner.com/time/business',
          'http://feeds2.feedburner.com/time/politics',
          'http://rss.cnn.com/rss/edition.rss',
          'http://rss.cnn.com/rss/edition_world.rss',
          'http://www.nytimes.com/services/xml/rss/nyt/GlobalHome.xml',
          'http://feeds.nytimes.com/nyt/rss/Business',
          'http://www.nytimes.com/services/xml/rss/nyt/World.xml',
          'http://www.nytimes.com/services/xml/rss/nyt/Economy.xml'
          ]

# %%
def stripHTML(h):
  p=''
  s=0
  for c in h:
    if c=='<': s=1
    elif c=='>':
      s=0
      p+=' '
    elif s==0: p+=c
  return p

# %% [markdown]
# ## Anlegen der Artikel/Wort-Matrix
#
# ### Die Funktion _getarticlewords()_
# Schreiben Sie eine Funktion _getarticlewords()_, die folgende Elemente zurückgibt:
#
# * _allwords:_ ist ein Dictionary dessen Keys die Worte aller gesammelten Artikel sind. Der zu jedem Key gehörende Wert ist die Anzahl, wie oft das Wort insgesamt vorkommt.
# * _articlewords:_ ist eine Liste mit so vielen Elementen wie Artikel in der Sammlung sind. Jedes Listenelement ist ein Dictionary, welches die Worte des jeweiligen Artikels als Key enthält und als Wert die Worthäufigkeit.
# * _articletitles_ ist eine Liste mit so vielen Elementen wie Artikel in der Sammlung sind. Jedes Element ist der Artikeltitel als String.
#
# Für das Parsing der Feeds soll wieder das Modul _feedparser_ eingesetzt werden. Die zu einer Nachricht gehörenden Wörter sollen die Wörter des Elements _title_ und die Wörter des Elements _description_ sein (siehe voriger Versuch). Allerdings sollen hier nicht alle Wörter eingebunden werden, sondern wie im vorigen Versuch eine Methode _getwords()_ implementiert werden, welche nur die _relevanten_ Wörter zurückgibt. Die Frage welche Wörter relevant sind ist nicht eindeutig beantwortbar. Sie können sich hierzu eigene Antworten einfallen lassen. Auf jeden Fall sollten aber die Stopwörter ignoriert werden. Hierzu kann z.B. die Stopwortliste von NLTK angewandt werden.
#
# Nachdem alle relevanten Wörter aller Nachrichten gesammelt sind, sollte eine weitere Bereinigung stattfinden, die
#
# * alle Wörter, die weniger als 4 mal vorkommen
# * alle Wörter, die in mehr als 30% aller Dokumente vorkommen
#
# entfernt.
#
# Durch dieses Herausfiltern nicht relevanter Wörter kann es vorkommen, dass einzelne Artikel keine relevanten Wörter mehr enthalten. Diese Artikel sollen dann ganz ignoriert werden. D.h. unter anderem, dass diese Artikel auch nicht in _articlewords_ und _articletitles_ erscheinen.

# %%
from nltk.corpus import stopwords
from nltk import word_tokenize
from itertools import dropwhile

# Remove stopwords and transform to lowercase
def getwords(text):
    stop = set(stopwords.words('english'))
    return [i.lower() for i in word_tokenize(text) if i not in stop and len(i) > 3]

def findIrrelevant(words, min_frequency, max_percentage):
    word_sum = sum(words.values())
    return {word for word, frequency in words.items() if frequency <= min_frequency or float(frequency)/word_sum > max_percentage}

def getarticlewords(feed):
    allwords = dict()
    articlewords = list()
    articletitles = list()
    f=feedparser.parse(feed)
    for article in f.entries:
        if 'description' in article and 'title' in article:
            fulltext = stripHTML(article.title + ' ' + article.description)
            words = getwords(fulltext)
            articleword = dict()
            for word in words:
                if word in articleword:
                    articleword[word] += 1
                else:
                    articleword[word] = 1
                    
                if word in allwords:
                    allwords[word] += 1
                else:
                    allwords[word] = 1
            articlewords.append(articleword)
            articletitles.append(article.title)
            
    irrelevant_words = findIrrelevant(allwords, 2, 0.5)
    
    for word in irrelevant_words:
        del allwords[word]
        
        for articleword in articlewords:
            if word in articleword:
                del articleword[word]
                
    if not allwords:
        return None
    
    articlewords, articletitles = zip(*[(articleword, title) for articleword, title in zip(articlewords, articletitles) if articleword])
        
    return (allwords, np.array(articlewords), np.array(articletitles))

# %% [markdown]
# ### Die Funktion _makematrix()_
# Schreiben Sie eine Funktion _makematrix()_, die aus dem Dictionary _allwords_ und der Liste _articlewords_ (vorige Aufgabe) die Artikel-/Wort-Matrix generiert. Die Einträge in der Matrix sollen die Häufigkeiten der Wörter im jeweiligen Dokument sein (term frequency tf). Die Artikel-/Wort-Matrix soll als 2-dimensionales Numpy Array angelegt werden.

# %%
def makematrix(allwords, articlewords):
    words = allwords.keys()
    article_word_matrix = np.zeros((len(articlewords), len(words)))
    for i in range(len(article_word_matrix)):
        row = article_word_matrix[i]
        current_articlewords = articlewords[i]
        for word in current_articlewords.keys():
            row[words.index(word)] = current_articlewords[word]
    return (np.matrix(article_word_matrix), words)

# %% [markdown]
# ## Die Nicht Negative Matrix Faktorisierung
# Die Implementierung der NNMF ist entsprechend der Beschreibung im Theoriekapitel durchzuführen.
#
# * Implementieren Sie die Funktion _cost(A,B)_. Dieser Funktion werden zwei Numpy-Matrizen $A$ und $B$ übergeben. Zurück geliefert werden die nach oben angegebener Formel berechneten Kosten $k$. Diese Funktion wird von der im folgenden beschriebenen Funktion _nnmf(A,m,it)_ benutzt.
# * Implementieren Sie die Funktion __nnmf(A,m,it)__. In dieser Funktion soll der oben beschriebene Algorithmus für die Nicht-negative Matrix Faktorisierung ausgeführt werden. Der Funktion wird die zu faktorisierende Matrix $A$, die Anzahl der Merkmale $m$ und die Anzahl der Iterationen $it$ übergeben. Die Funktion gibt die gefundenen Faktoren $W$ und $H$ zurück. In jeder Iteration sollen mit der Funktion __cost(A,B)__ die Kosten berechnet werden. Sobald die Kostenabnahme pro 10 Iterationen kleiner als $2$ ist oder eine maximale Anzahl von Iterationen ($maxIt=200$) erreicht ist, soll der Algorithmus mit der Rückgabe der Faktoren $W$ und $H$ terminieren.
#
#
# Tipp für die Implementierung elementweiser Operationen von Matrizen: Für elementweise Operationen müssen in Python/Numpy nicht alle Elemente über Schleifen explizit berechnet werden. Eine elementweise Anpassung aller Matrixelemente kann kompakt programmiert werden indem die beteiligten Matrizen für diese Operationen als Arrays implementiert werden. Sollen z.B. die beiden gleich großen Numpy Arrays $U$ und $V$ elementweise multipliziert werden, dann wäre der entsprechende Programmcode einfach _U*V_.

# %%
def cost(A, B):
    return np.sum(np.square(A - B))
    
def nnmf(A, m, it):
    (r, c) = A.shape
    
    if not m < c:
        raise ValueError()
         
    B = None
    
    cost_iteration = 0
    cost_start = None
    cost_current = None
    
    H = np.matrix(np.random.random((m, c)))
    W = np.matrix(np.random.random((r, m)))

    for i in range(it): 
        cost_iteration += 1
        
        if cost_iteration == 10:
            if cost_start - cost_current > 2:
                cost_iteration = 0
                cost_start = cost_current
            else:
                break
      
        B = W * H
        
        _cost = cost(A, B)
        
        if not cost_start:
            cost_start = _cost
        
        cost_current = _cost
        
        H = np.multiply(H, (W.T * A)/(W.T*W*H))
        W = np.multiply(W, (A * H.T)/(W*H*H.T))
 
    return (W, H)

from sklearn.decomposition import NMF

def nnmfsk(A, m, it):
    nmf_model = NMF(n_components=m, init='random', random_state=0, max_iter=it)
    W = nmf_model.fit_transform(A)
    H = nmf_model.components_
    return (W, H)

# %% [markdown]
# ## Anzeige der Merkmale und der Gewichte
#
# Im vorigen Abschnitt wurde die Merkmalsmatrix $H$ und die Gewichtsmatrix $W$ berechnet. Diese Matrizen können natürlich am Bildschirm ausgegeben werden, was jedoch nicht besonders informativ ist. Aus den Matrizen können jedoch die Antworten für die folgenden interessanten Fragen berechnet werden:
#
# * In welchen Artikeln sind welche Merkmale stark vertreten?
# * Wie lassen sich die insgesamt $m$ Merkmale beschreiben, so dass aus dieser Merkmalsbeschreibung klar wird, welches Thema den Artikeln, in denen das Merkmal stark vertreten ist, behandelt wird?
#
# Die Antwort auf die erste Frage ergibt sich aus der Gewichtsmatrix $W$. Für die Beantwortung der zweiten Frage wird die Merkmalsmatrix $H$ herangezogen.
#
#
#
# ### Beschreibung der Merkmale
#
# Die Merkmalsmatrix $H$ beschreibt, wie stark die Worte aus _wordvec_ in jedem Merkmal enthalten sind. Jede Zeile von $H$ gehört zu einem Merkmal, jede Spalte von $H$ gehört zu einem Wort in _wordvec_.
#
# Es bietet sich an jedes Merkmal einfach durch die $N=6$ Wörter aus _wordvec_ zu beschreiben, welche am stärksten in diesem Merkmal enthalten sind. Hierzu muss für jedes Merkmal die entsprechende Zeile in $H$ nach den $N=6$ größten Werten durchsucht bzw. geordnet werden. Die entsprechenden Spalten dieser Matrixelemente verweisen dann auf die $N=6$ wichtigsten Worte des Merkmals.
#
# Tipp für die Implementierung: Legen Sie für jedes Merkmal $i$ eine Liste an. Die Listenlänge ist durch die Anzahl der Worte in _wordvec_ (d.h. die Anzahl der Spalten in $H$) gegeben. Jedes Listenelement $j$ enthält selbst wieder 2 Elemente: An erster Stelle den entsprechenden Wert $H_{i,j}$ der Merkmalsmatrix, an der zweiten Stelle das $j.$-te Wort in _wordvec_. Nachdem die Liste angelegt ist, kann sie mit _listname.sort()_ in aufsteigender Reihenfolge sortiert werden. Die abnehmende Sortierung erhält man mit _listname.sort().reverse()_. Danach geben die $N=6$ ersten Listenelemente die für das Merkmal $i$ wichtigsten Worte an.
#
#
# ### Präsenz der Merkmale in den Artikeln
#
# Die Gewichtsmatrix $W$ beschreibt, wie stark die $m$ Merkmale in den Artikeln aus _articletitles_ enthalten sind. Jede Zeile von $W$ gehört zu einem Artikel, jede Spalte von $W$ gehört zu einem Merkmal.
# Die Berechnung der $M=2$ gewichtigsten Merkmale für jeden Artikel in _articletitles_ kann analog zu der oben beschriebenen Berechnung der $N=6$ wichtigsten Worte eines Merkmals berechnet werden.
#
#
# ### Implementierung
#
# Implementieren Sie eine Funktion _showfeatures(w,h,titles,wordvec)_, welche wie oben beschrieben für jeden Artikel die $M=2$ wichtigsten Merkmale am Bildschirm ausgibt. Dabei soll jedes Merkmal durch die 6 wichtigsten Wörter dieses Merkmals angegeben werden. Siehe Beispielausgabe unten.
#
# Übergabeparameter der Funktion sind die Merkmalsmatrix $H$, die Gewichtungsmatrix $W$, die Liste aller Artikeltitel _articletitles_ und die Liste aller Worte _wordvec_.
#
#
# Beispiel fuer Ausgabe:

# %% [markdown]
# [(13.54131155883748, 13, u'Putin vows payback after confirmation of Egypt plane bomb'),
#
# (2.2466669548146254, 9, u'Putin vows payback after confirmation of Egypt plane bomb')]
#
# ----- ['plane', 'egypt', 'russia', 'month', 'killing', 'putin']
#
# ----- ['airport', 'russian', 'crash', 'egypt', 'security', 'officials']

# %% [markdown]
# Die Ausgabe ist wie folgt zu interpretieren:
# * Für den Artikel _Putin vows payback after confirmation of Egypt plane bomb_ ist
#     * das wichtigste Merkmal durch die 6 Wörter _plane_, _egypt_, _russia_, _month_, _killing_, _putin_ definiert. Das Gewicht dieses Merkmals im Artikel ist 13.54
#     * das zweitwichtigste Merkmal durch die 6 Wörter _airport_, _russian_, _crash_, _egypt_, _security_, _officials_ definiert. Das Gewicht dieses Merkmals im Artikel ist 2.24

# %%
def showfeatures(w, h, titles, wordvec):
    features = [(sorted(zip(feature, wordvec), reverse=True))[:6] for feature in np.array(h)]
    article_features = zip([sorted(zip(article, range(len(article))), reverse=True)[:2] for article in np.array(w)], titles)
    for feature_weights, article in article_features:
        print feature_weights, article
        for weight, feature_index in feature_weights:
            print '-------', zip(*features[feature_index])[1]
    
for feed in feedlist:
    article_words = getarticlewords(feed)
    if article_words:
        matrix, wordvec = makematrix(article_words[0], article_words[1])
        if (matrix.shape[1] > 10):
            W, H = nnmf(matrix, 5, 200)
            showfeatures(W, H, article_words[2], wordvec)
# Out:
# [(2.4590542477103976, 0), (1.2872793554983557, 1)] Trump says he will back away from business to focus on White House
# ------- (u'running', u'trump', u'reuters', u'says', u'avoid', u'wednesday')
# ------- (u'says', u'thursday', u'avoid', u'reuters', u'korea', u'trump')
# [(0.7778399361830961, 4), (0.15180685618726653, 0)] Oil price rally likely short-lived as OPEC deal not enough to reduce glut
# ------- (u'reuters', u'death', u'avoid', u'wednesday', u'park', u'running')
# ------- (u'running', u'trump', u'reuters', u'says', u'avoid', u'wednesday')
# [(2.7069954752904306, 0), (0.18724460868707116, 4)] Soccer plane in Colombia crash was running out of fuel: recording
# ------- (u'running', u'trump', u'reuters', u'says', u'avoid', u'wednesday')
# ------- (u'reuters', u'death', u'avoid', u'wednesday', u'park', u'running')
# [(0.9765078423840311, 2), (0.93423630252412626, 4)] Reunited in death: Fidel Castro's remains rest at Che Guevara mausoleum
# ------- (u'wednesday', u'death', u'trump', u'park', u'reuters', u'says')
# ------- (u'reuters', u'death', u'avoid', u'wednesday', u'park', u'running')
# [(1.6991524253181554, 2), (1.0976383208814138, 4)] Death toll rises to seven in Tennessee's Great Smoky Mountains fires
# ------- (u'wednesday', u'death', u'trump', u'park', u'reuters', u'says')
# ------- (u'reuters', u'death', u'avoid', u'wednesday', u'park', u'running')
# [(1.7949929837007128, 1), (0.68247783507675319, 0)] Putin curbs anti-Western rhetoric, says wants to get on with Trump
# ------- (u'says', u'thursday', u'avoid', u'reuters', u'korea', u'trump')
# ------- (u'running', u'trump', u'reuters', u'says', u'avoid', u'wednesday')
# [(2.9218330418647334, 1), (0.36814903536516802, 4)] Ukraine says missile tests will avoid Crimea, mollifying Russia
# ------- (u'says', u'thursday', u'avoid', u'reuters', u'korea', u'trump')
# ------- (u'reuters', u'death', u'avoid', u'wednesday', u'park', u'running')
# [(0.89283097543897483, 0), (0.50507765287792583, 4)] Separation anxiety: Trump’s management style poses challenges in Oval Office
# ------- (u'running', u'trump', u'reuters', u'says', u'avoid', u'wednesday')
# ------- (u'reuters', u'death', u'avoid', u'wednesday', u'park', u'running')
# [(2.2500245340555933, 1), (0.7531709824763928, 3)] China says new North Korea sanctions not meant to harm 'normal' trade
# ------- (u'says', u'thursday', u'avoid', u'reuters', u'korea', u'trump')
# ------- (u'south', u'korea', u'park', u'reuters', u'thursday', u'says')
# [(3.5091320655861309, 3), (0.041789604910345036, 2)] Fire and loathing in former stronghold of South Korea's Park
# ------- (u'south', u'korea', u'park', u'reuters', u'thursday', u'says')
# ------- (u'wednesday', u'death', u'trump', u'park', u'reuters', u'says')
# [(3.8051134413597718, 3), (0.069824429819022052, 1)] Oil price rally likely short-lived as OPEC deal not enough to reduce glut
# ------- (u'rally', u'price', u'deal', u'opec', u'reuters', u'united')
# ------- (u'trump', u'united', u'donald', u'reuters', u'price', u'rally')
# [(1.7553431293377302, 0), (0.91583579521577563, 3)] Oil hits six-week high after OPEC deal, bond yields rise
# ------- (u'reuters', u'london', u'minister', u'prime', u'opec', u'deal')
# ------- (u'rally', u'price', u'deal', u'opec', u'reuters', u'united')
# [(1.0754436741142388, 1), (0.2226809943809227, 0)] Separation anxiety: Trump’s management style poses challenges in Oval Office
# ------- (u'trump', u'united', u'donald', u'reuters', u'price', u'rally')
# ------- (u'reuters', u'london', u'minister', u'prime', u'opec', u'deal')
# [(2.2518348082435957, 1), (0.046728277298945381, 3)] Carrier gets state incentives, Trump pledge for keeping U.S. jobs
# ------- (u'trump', u'united', u'donald', u'reuters', u'price', u'rally')
# ------- (u'rally', u'price', u'deal', u'opec', u'reuters', u'united')
# [(1.9658180102228997, 0), (0.25560368130151306, 4)] Markets swing violently against Italy without clear idea of outcome
# ------- (u'reuters', u'london', u'minister', u'prime', u'opec', u'deal')
# ------- (u'coal', u'prime', u'minister', u'reuters', u'rally', u'price')
# [(0.99933747252874916, 3), (0.98466085201503872, 1)] Global factories had bumper November but growth may have peaked
# ------- (u'rally', u'price', u'deal', u'opec', u'reuters', u'united')
# ------- (u'trump', u'united', u'donald', u'reuters', u'price', u'rally')
# [(1.9658948755149392, 0), (0.25545401382566146, 4)] Britain to decide how to spend taxpayers' money post-Brexit: PM May's spokeswoman
# ------- (u'reuters', u'london', u'minister', u'prime', u'opec', u'deal')
# ------- (u'coal', u'prime', u'minister', u'reuters', u'rally', u'price')
# [(3.831947973716165, 4), (0.065859347922739883, 0)] Exclusive: Indian government officials propose break-up of Coal India - sources
# ------- (u'coal', u'prime', u'minister', u'reuters', u'rally', u'price')
# ------- (u'reuters', u'london', u'minister', u'prime', u'opec', u'deal')
# [(1.108961851170452, 0), (0.46577594710964032, 2)] ChemChina setting up $5 billion fund to help finance Syngenta bid: Basis Point
# ------- (u'reuters', u'london', u'minister', u'prime', u'opec', u'deal')
# ------- (u'nokia', u'reuters', u'rally', u'price', u'donald', u'deal')
# [(3.7253878237505611, 2), (0.0068216606836561961, 1)] Nokia brand-phones poised for comeback as HMD takes charge
# ------- (u'nokia', u'reuters', u'rally', u'price', u'donald', u'deal')
# ------- (u'trump', u'united', u'donald', u'reuters', u'price', u'rally')
# [(3.9988510074201731, 4), (0.0, 3)] From paradise to plastic wasteland
# ------- (u'plastic', u'walsh', u'paton', u'nick', u'water', u'what')
# ------- (u'brexit', u'europe', u'trump', u'what', u'could', u'donald')
# [(4.050165793675597, 4), (0.19390745943227691, 3)] What is a microplastic?
# ------- (u'plastic', u'walsh', u'paton', u'nick', u'water', u'what')
# ------- (u'brexit', u'europe', u'trump', u'what', u'could', u'donald')
# [(0.38944934754182614, 4), (0.073107404236305504, 3)] Crashed jet: 'Total electrical failure and without fuel'
# ------- (u'plastic', u'walsh', u'paton', u'nick', u'water', u'what')
# ------- (u'brexit', u'europe', u'trump', u'what', u'could', u'donald')
# [(0.18701185939082182, 4), (2.0609457943284345e-08, 1)] Rebels band together as regime attacks
# ------- (u'plastic', u'walsh', u'paton', u'nick', u'water', u'what')
# ------- (u'carter', u'president', u'obama', u'said', u'trump', u'water')
# [(1.1130522719919551, 1), (0.15699990125857025, 0)] Putin: Ready to work with new US leader
# ------- (u'carter', u'president', u'obama', u'said', u'trump', u'water')
# ------- (u'trump', u'donald', u'said', u'europe', u'brexit', u'president')
# [(5.0049036750241935, 0), (0.12881983152271009, 3)] Trump interviews generals he's criticized
# ------- (u'trump', u'donald', u'said', u'europe', u'brexit', u'president')
# ------- (u'brexit', u'europe', u'trump', u'what', u'could', u'donald')
# [(3.5477806553415854, 0), (0.072663537874248549, 3)] Trump stakes his negotiating credibility
# ------- (u'trump', u'donald', u'said', u'europe', u'brexit', u'president')
# ------- (u'brexit', u'europe', u'trump', u'what', u'could', u'donald')
# [(0.13061891102412998, 2), (0.038703603538857156, 4)] Millions of China's 'missing girls' exist
# ------- (u'massive', u'could', u'youth', u'people', u'without', u'china')
# ------- (u'plastic', u'walsh', u'paton', u'nick', u'water', u'what')
# [(1.6528318027080582, 4), (0.0010200332603431499, 2)] ISIS uses water as weapon in Mosul
# ------- (u'plastic', u'walsh', u'paton', u'nick', u'water', u'what')
# ------- (u'massive', u'could', u'youth', u'people', u'without', u'china')
# [(5.1375973177382397, 2), (0.0030395311219457498, 3)] Chernobyl gets massive shield
# ------- (u'massive', u'could', u'youth', u'people', u'without', u'china')
# ------- (u'brexit', u'europe', u'trump', u'what', u'could', u'donald')
# [(1.8039125260169444, 0), (0.16878329171460149, 1)] Did Trump call Pakistan's PM 'terrific'?
# ------- (u'trump', u'donald', u'said', u'europe', u'brexit', u'president')
# ------- (u'carter', u'president', u'obama', u'said', u'trump', u'water')
# [(3.5482226866566653, 0), (0.07165347163982308, 3)] How Trump keeps fit
# ------- (u'trump', u'donald', u'said', u'europe', u'brexit', u'president')
# ------- (u'brexit', u'europe', u'trump', u'what', u'could', u'donald')
# [(3.8274415867656573, 3), (2.0690638057351252, 0)] Can Europe survive the Trump effect?
# ------- (u'brexit', u'europe', u'trump', u'what', u'could', u'donald')
# ------- (u'trump', u'donald', u'said', u'europe', u'brexit', u'president')
# [(3.3133838219275309, 2), (0.048880124170594452, 3)] Bracelet that could stop child predators
# ------- (u'massive', u'could', u'youth', u'people', u'without', u'china')
# ------- (u'brexit', u'europe', u'trump', u'what', u'could', u'donald')
# [(0.37357138664209399, 3), (0.33112665217459475, 4)] What the sex robots will teach us
# ------- (u'brexit', u'europe', u'trump', u'what', u'could', u'donald')
# ------- (u'plastic', u'walsh', u'paton', u'nick', u'water', u'what')
# [(0.070541524468199598, 2), (0.019959978370449653, 4)] China builds full-size replica of Titanic
# ------- (u'massive', u'could', u'youth', u'people', u'without', u'china')
# ------- (u'plastic', u'walsh', u'paton', u'nick', u'water', u'what')
# [(0.77493013829271407, 4), (4.803175857981653e-08, 1)] Crystal clear water where fish swim up to your feet
# ------- (u'plastic', u'walsh', u'paton', u'nick', u'water', u'what')
# ------- (u'carter', u'president', u'obama', u'said', u'trump', u'water')
# [(0.19983148485959795, 4), (0.14597872628483344, 2)] Lack of sex ed puts lives at risk in China
# ------- (u'plastic', u'walsh', u'paton', u'nick', u'water', u'what')
# ------- (u'massive', u'could', u'youth', u'people', u'without', u'china')
# [(0.00020299909922130908, 3), (2.1732243828653092e-13, 1)] Being a 'superhero': HIV vaccine volunteers
# ------- (u'brexit', u'europe', u'trump', u'what', u'could', u'donald')
# ------- (u'carter', u'president', u'obama', u'said', u'trump', u'water')
# [(0.001060433385462858, 3), (1.5843607834681723e-14, 1)] Life as a teen who was born with HIV
# ------- (u'brexit', u'europe', u'trump', u'what', u'could', u'donald')
# ------- (u'carter', u'president', u'obama', u'said', u'trump', u'water')
# [(2.4144118776950938, 2), (0.16023796978862062, 4)] AIDS is still a new threat to a younger generation
# ------- (u'massive', u'could', u'youth', u'people', u'without', u'china')
# ------- (u'plastic', u'walsh', u'paton', u'nick', u'water', u'what')
# [(2.517946414106595, 3), (1.1017676915570673, 0)] In 2017, France and Germany will split Europe in two
# ------- (u'brexit', u'europe', u'trump', u'what', u'could', u'donald')
# ------- (u'trump', u'donald', u'said', u'europe', u'brexit', u'president')
# [(6.3603565284298869, 1), (0.00076425509204571212, 2)] Why Carter is wrong on State of Palestine
# ------- (u'carter', u'president', u'obama', u'said', u'trump', u'water')
# ------- (u'massive', u'could', u'youth', u'people', u'without', u'china')
# [(0.5276094642696828, 4), (0.50725613152816518, 3)] Pilot: What may have happened in Colombia plane crash
# ------- (u'plastic', u'walsh', u'paton', u'nick', u'water', u'what')
# ------- (u'brexit', u'europe', u'trump', u'what', u'could', u'donald')
# [(0.00020299909922130908, 3), (2.1732243828653092e-13, 1)] Saving children from life on the streets
# ------- (u'brexit', u'europe', u'trump', u'what', u'could', u'donald')
# ------- (u'carter', u'president', u'obama', u'said', u'trump', u'water')
# [(0.13061891102412998, 2), (0.038703603538857149, 4)] Girls drugged and sold as child brides
# ------- (u'massive', u'could', u'youth', u'people', u'without', u'china')
# ------- (u'plastic', u'walsh', u'paton', u'nick', u'water', u'what')
# [(0.0086266926064861426, 3), (4.1418236382291336e-247, 2)] The '5 disguises' used by human traffickers
# ------- (u'brexit', u'europe', u'trump', u'what', u'could', u'donald')
# ------- (u'massive', u'could', u'youth', u'people', u'without', u'china')
# [(4.8054581054125016, 3), (1.0373881273009602, 0)] Populism: What next after Trump and Brexit?
# ------- (u'brexit', u'europe', u'trump', u'what', u'could', u'donald')
# ------- (u'trump', u'donald', u'said', u'europe', u'brexit', u'president')
# [(2.2463399544276799, 4), (0.0, 3)] How soldiers survive in the Arctic
# ------- (u'plastic', u'walsh', u'paton', u'nick', u'water', u'what')
# ------- (u'brexit', u'europe', u'trump', u'what', u'could', u'donald')
# [(2.4396923811887645, 1), (0.0019412737368680025, 2)] Obama's finest fist bumps
# ------- (u'carter', u'president', u'obama', u'said', u'trump', u'water')
# ------- (u'massive', u'could', u'youth', u'people', u'without', u'china')
# [(3.1893172091143982, 3), (0.32942105153645462, 2)] ISIS uses water as weapon in Mosul fight
# ------- (u'mosul', u'inside', u'isis', u'liberated', u'people', u'city')
# ------- (u'trump', u'jobs', u'donald', u'wednesday', u'president', u'deal')
# [(3.9741190986890729, 3), (5.5566975497259438e-28, 4)] Inside liberated Mosul neighborhoods
# ------- (u'mosul', u'inside', u'isis', u'liberated', u'people', u'city')
# ------- (u'must', u'carter', u'president', u'play', u'movie', u'wednesday')
# [(1.4123229767159993, 3), (4.7192310425489539e-21, 2)] Mosul operation: Iraqi-led forces push into key city
# ------- (u'mosul', u'inside', u'isis', u'liberated', u'people', u'city')
# ------- (u'trump', u'jobs', u'donald', u'wednesday', u'president', u'deal')
# [(2.413573810537347, 3), (1.8524967590631193e-30, 4)] Slaughter of innocents continues in battle for Mosul
# ------- (u'mosul', u'inside', u'isis', u'liberated', u'people', u'city')
# ------- (u'must', u'carter', u'president', u'play', u'movie', u'wednesday')
# [(1.6955696060217831, 1), (0.10444127627120998, 2)] North Korea's Nazi-style prison camps
# ------- (u'mars', u'could', u'mission', u'korea', u'north', u'journey')
# ------- (u'trump', u'jobs', u'donald', u'wednesday', u'president', u'deal')
# [(5.8581720349290487, 0), (0.14166718244242052, 1)] Fidel Castro's ashes start journey across Cuba
# ------- (u'castro', u'fidel', u'across', u'journey', u'wednesday', u'movie')
# ------- (u'mars', u'could', u'mission', u'korea', u'north', u'journey')
# [(3.0294067452830626, 0), (2.5808759091153665e-151, 1)] What Fidel Castro funeral RSVPs say about the world
# ------- (u'castro', u'fidel', u'across', u'journey', u'wednesday', u'movie')
# ------- (u'mars', u'could', u'mission', u'korea', u'north', u'journey')
# [(0.47159091972290368, 2), (0.43779063974563104, 3)] 'Biggest massacre' since WW2; war goes on
# ------- (u'trump', u'jobs', u'donald', u'wednesday', u'president', u'deal')
# ------- (u'mosul', u'inside', u'isis', u'liberated', u'people', u'city')
# [(1.764779900221767, 1), (0.39939253153319465, 2)] More sanctions for North Korea over nuke test
# ------- (u'mars', u'could', u'mission', u'korea', u'north', u'journey')
# ------- (u'trump', u'jobs', u'donald', u'wednesday', u'president', u'deal')
# [(0.29985935910087119, 3), (1.1494441212286232e-18, 4)] Holocaust survivor: Don't let far right win
# ------- (u'mosul', u'inside', u'isis', u'liberated', u'people', u'city')
# ------- (u'must', u'carter', u'president', u'play', u'movie', u'wednesday')
# [(3.0631100799519388, 2), (0.13473042879096112, 3)] Putin and Trump agree on this
# ------- (u'trump', u'jobs', u'donald', u'wednesday', u'president', u'deal')
# ------- (u'mosul', u'inside', u'isis', u'liberated', u'people', u'city')
# [(0.29985935910087119, 3), (1.1546913521297341e-18, 4)] The teenage refugees selling sex on Athens streets
# ------- (u'mosul', u'inside', u'isis', u'liberated', u'people', u'city')
# ------- (u'must', u'carter', u'president', u'play', u'movie', u'wednesday')
# [(3.3758823179210857, 4), (0.50240436964014845, 0)] Movie theaters here must play the national anthem
# ------- (u'must', u'carter', u'president', u'play', u'movie', u'wednesday')
# ------- (u'castro', u'fidel', u'across', u'journey', u'wednesday', u'movie')
# [(0.61903426700834707, 1), (5.3002627639470127e-33, 4)] Giant shield slides into place over Chernobyl's damaged reactor
# ------- (u'mars', u'could', u'mission', u'korea', u'north', u'journey')
# ------- (u'must', u'carter', u'president', u'play', u'movie', u'wednesday')
# [(0.75081845251421964, 4), (0.66773371251695768, 1)] Italy for eaters: 9 destinations that'll destroy your waistline
# ------- (u'must', u'carter', u'president', u'play', u'movie', u'wednesday')
# ------- (u'mars', u'could', u'mission', u'korea', u'north', u'journey')
# [(1.3332660745152807, 2), (7.9424302488577419e-49, 0)] In 2017, France and Germany will split Europe in two
# ------- (u'trump', u'jobs', u'donald', u'wednesday', u'president', u'deal')
# ------- (u'castro', u'fidel', u'across', u'journey', u'wednesday', u'movie')
# [(4.6027328133242005, 4), (0.072621721811321427, 2)] Why Carter is wrong on State of Palestine
# ------- (u'must', u'carter', u'president', u'play', u'movie', u'wednesday')
# ------- (u'trump', u'jobs', u'donald', u'wednesday', u'president', u'deal')
# [(0.44762427244804054, 2), (0.0, 4)] Oil prices surge on optimism over OPEC deal
# ------- (u'trump', u'jobs', u'donald', u'wednesday', u'president', u'deal')
# ------- (u'must', u'carter', u'president', u'play', u'movie', u'wednesday')
# [(2.8696611158745537, 2), (0.31348638752355984, 4)] Trump vows to 'remove' himself from business
# ------- (u'trump', u'jobs', u'donald', u'wednesday', u'president', u'deal')
# ------- (u'must', u'carter', u'president', u'play', u'movie', u'wednesday')
# [(3.834652081055645, 2), (1.4986964833337896e-91, 0)] Good luck getting those jobs back, China says
# ------- (u'trump', u'jobs', u'donald', u'wednesday', u'president', u'deal')
# ------- (u'castro', u'fidel', u'across', u'journey', u'wednesday', u'movie')
# [(0.87775812476090076, 1), (0.35040832470041472, 0)] A new perspective of our planet
# ------- (u'mars', u'could', u'mission', u'korea', u'north', u'journey')
# ------- (u'castro', u'fidel', u'across', u'journey', u'wednesday', u'movie')
# [(4.1863163316630141, 1), (0.032630431869914468, 0)] Study: Mars mission astronauts could experience brain damage
# ------- (u'mars', u'could', u'mission', u'korea', u'north', u'journey')
# ------- (u'castro', u'fidel', u'across', u'journey', u'wednesday', u'movie')
# [(1.4454155205129269, 1), (1.2675393548308107e-290, 0)] New Mars probe searches for life
# ------- (u'mars', u'could', u'mission', u'korea', u'north', u'journey')
# ------- (u'castro', u'fidel', u'across', u'journey', u'wednesday', u'movie')
# [(1.1202514070684917, 3), (0.14563661620203255, 4)] Trump’s Economic Cabinet Picks Signal Embrace of Wall St. Elite
# ------- (u'trump', u'donald', u'president-elect', u'tuesday', u'manhattan', u'state')
# ------- (u'carrier', u'jobs', u'trump', u'left', u'president-elect', u'york')
# [(3.3414416509897431, 3), (1.1678675192178345, 4)] Transition Briefing: Trump Heads to Indiana to Bask, as Democrats Take Aim at Nominees
# ------- (u'trump', u'donald', u'president-elect', u'tuesday', u'manhattan', u'state')
# ------- (u'carrier', u'jobs', u'trump', u'left', u'president-elect', u'york')
# [(6.9471198718079412, 4), (0.0016059613231492419, 3)] Trump Saved Jobs at Carrier, but More Midwest Jobs Are in Jeopardy
# ------- (u'carrier', u'jobs', u'trump', u'left', u'president-elect', u'york')
# ------- (u'trump', u'donald', u'president-elect', u'tuesday', u'manhattan', u'state')
# [(4.086713359005965, 3), (0.32798054339318811, 4)] Political Memo: Trump, a Free-Form Leader, Experiments and Invites Drama
# ------- (u'trump', u'donald', u'president-elect', u'tuesday', u'manhattan', u'state')
# ------- (u'carrier', u'jobs', u'trump', u'left', u'president-elect', u'york')
# [(4.5912255070481773, 3), (0.56535608391046677, 2)] Ethics Office Praises Donald Trump for a Move He Hasn’t Committed To
# ------- (u'trump', u'donald', u'president-elect', u'tuesday', u'manhattan', u'state')
# ------- (u'police', u'wednesday', u'officer', u'house', u'race', u'scott')
# [(4.1776700547029328, 3), (0.0055264714025440318, 4)] Work-Life Balance: What Donald Trump Might Do for Working-Class Families
# ------- (u'trump', u'donald', u'president-elect', u'tuesday', u'manhattan', u'state')
# ------- (u'carrier', u'jobs', u'trump', u'left', u'president-elect', u'york')
# [(4.0594390379754239, 3), (0.021587160520490888, 4)] News Analysis: Why the Trump Team’s Economic Promises Will Be Hard to Execute
# ------- (u'trump', u'donald', u'president-elect', u'tuesday', u'manhattan', u'state')
# ------- (u'carrier', u'jobs', u'trump', u'left', u'president-elect', u'york')
# [(1.4931417273577996, 2), (0.0, 4)] Nancy Pelosi Beats Back House Democratic Leadership Challenge
# ------- (u'police', u'wednesday', u'officer', u'house', u'race', u'scott')
# ------- (u'carrier', u'jobs', u'trump', u'left', u'president-elect', u'york')
# [(4.780037241644445, 2), (1.9789840986755582, 1)] Your Thursday Briefing
# ------- (u'police', u'wednesday', u'officer', u'house', u'race', u'scott')
# ------- (u'scott', u'officer', u'shooting', u'keith', u'said', u'wednesday')
# [(0.75691348257274327, 0), (2.8553122440546199e-17, 3)] New York Today: New York Today: Keeping a Christmas Tree Green
# ------- (u'deal', u'million', u'central', u'said', u'york', u'police')
# ------- (u'trump', u'donald', u'president-elect', u'tuesday', u'manhattan', u'state')
# [(2.5126330420129164, 2), (0.037266166418036928, 3)] Colombia’s Congress Approves Peace Accord With FARC
# ------- (u'police', u'wednesday', u'officer', u'house', u'race', u'scott')
# ------- (u'trump', u'donald', u'president-elect', u'tuesday', u'manhattan', u'state')
# [(6.2975250778667435, 1), (0.46699537301155364, 2)] Charlotte Officer ‘Justified’ in Fatal Shooting of Keith Scott
# ------- (u'scott', u'officer', u'shooting', u'keith', u'said', u'wednesday')
# ------- (u'police', u'wednesday', u'officer', u'house', u'race', u'scott')
# [(3.6135606264411337, 2), (1.4863657701325974, 1)] Charleston Jury Gets Case of Officer Who Killed Walter Scott
# ------- (u'police', u'wednesday', u'officer', u'house', u'race', u'scott')
# ------- (u'scott', u'officer', u'shooting', u'keith', u'said', u'wednesday')
# [(0.25001062655947648, 3), (0.024724709561470149, 0)] Doomed Jet Carrying Brazilian Team Reportedly Ran Out of Fuel
# ------- (u'trump', u'donald', u'president-elect', u'tuesday', u'manhattan', u'state')
# ------- (u'deal', u'million', u'central', u'said', u'york', u'police')
# [(1.4550743290415742, 2), (1.1107412483261296e-12, 1)] Partial Recount Ordered in North Carolina Governor’s Race
# ------- (u'police', u'wednesday', u'officer', u'house', u'race', u'scott')
# ------- (u'scott', u'officer', u'shooting', u'keith', u'said', u'wednesday')
# [(0.37845674128637163, 0), (2.7431724477450201e-17, 3)] U.S. Will Ban Smoking in Public Housing Nationwide
# ------- (u'deal', u'million', u'central', u'said', u'york', u'police')
# ------- (u'trump', u'donald', u'president-elect', u'tuesday', u'manhattan', u'state')
# [(0.53573484624991852, 3), (0.11661841954378566, 0)] Ohio State Attacker May Have Been ‘Inspired’ by Al Qaeda, F.B.I. Says
# ------- (u'trump', u'donald', u'president-elect', u'tuesday', u'manhattan', u'state')
# ------- (u'deal', u'million', u'central', u'said', u'york', u'police')
# [(1.6536737225217908e-11, 2), (0.0, 4)] Peer Out From a Bergdorf Goodman Window
# ------- (u'police', u'wednesday', u'officer', u'house', u'race', u'scott')
# ------- (u'carrier', u'jobs', u'trump', u'left', u'president-elect', u'york')
# [(8.2683686126089542e-12, 2), (0.0, 4)] Critic’s Notebook: We Need a Miracle on 34th Street
# ------- (u'police', u'wednesday', u'officer', u'house', u'race', u'scott')
# ------- (u'carrier', u'jobs', u'trump', u'left', u'president-elect', u'york')
# [(1.2461806420368284, 0), (1.2103006879922793e-05, 2)] Feature: How to Hide $400 Million
# ------- (u'deal', u'million', u'central', u'said', u'york', u'police')
# ------- (u'police', u'wednesday', u'officer', u'house', u'race', u'scott')
# [(1.0721047972970061, 2), (0.33025850809916141, 3)] Magnus Carlsen Overwhelms Challenger in Tiebreakers to Win World Chess Championship
# ------- (u'police', u'wednesday', u'officer', u'house', u'race', u'scott')
# ------- (u'trump', u'donald', u'president-elect', u'tuesday', u'manhattan', u'state')
# [(1.6388724087803908, 0), (1.4968654882899899, 2)] No Rainbow, but Thief Finds a Bucket of Gold on West 48th Street
# ------- (u'deal', u'million', u'central', u'said', u'york', u'police')
# ------- (u'police', u'wednesday', u'officer', u'house', u'race', u'scott')
# [(0.3594637322348519, 4), (0.027717965733284233, 0)] Can You Hear Agnes Martin’s Serenity in John Zorn’s Frenzied Music?
# ------- (u'carrier', u'jobs', u'trump', u'left', u'president-elect', u'york')
# ------- (u'deal', u'million', u'central', u'said', u'york', u'police')
# [(4.2751939854364904, 0), (0.21904095930367171, 1)] Mets Said to Re-Sign Yoenis Cespedes for Four Years, $110 Million
# ------- (u'deal', u'million', u'central', u'said', u'york', u'police')
# ------- (u'scott', u'officer', u'shooting', u'keith', u'said', u'wednesday')
# [(4.8170844134678212, 0), (1.9407886922298451e-39, 1)] After Comedy Central Cancellation, Larry Wilmore Signs Deal With ABC
# ------- (u'deal', u'million', u'central', u'said', u'york', u'police')
# ------- (u'scott', u'officer', u'shooting', u'keith', u'said', u'wednesday')
# [(1.246180642141052, 0), (1.2100935585094976e-05, 2)] Third Place? In Auction World, Phillips Is Making Strides
# ------- (u'deal', u'million', u'central', u'said', u'york', u'police')
# ------- (u'police', u'wednesday', u'officer', u'house', u'race', u'scott')
# [(1.0452038776397754, 0), (0.0, 4)] Tennessee Woman Accused of Coat-Hanger Abortion Attempt Faces New Charges
# ------- (u'deal', u'million', u'central', u'said', u'york', u'police')
# ------- (u'carrier', u'jobs', u'trump', u'left', u'president-elect', u'york')
# [(0.39319900812073616, 0), (0.355764590778617, 3)] The Neediest Cases: Raising 2 Young Children by Herself, in a Space That Feels Not Big Enough
# ------- (u'deal', u'million', u'central', u'said', u'york', u'police')
# ------- (u'trump', u'donald', u'president-elect', u'tuesday', u'manhattan', u'state')
# [(0.22153784663629747, 1), (2.833977481492316e-17, 4)] As Auto Lending Rises, So Do Delinquencies
# ------- (u'trump', u'tuesday', u'donald', u'tower', u'president-elect', u'could')
# ------- (u'donald', u'trump', u'said', u'government', u'wednesday', u'president-elect')
# [(1.84252516854411, 2), (0.018651963776038196, 0)] Though Awash in Fakes, China Rethinks Counterfeit Hunters
# ------- (u'coal', u'china', u'more', u'products', u'could', u'economic')
# ------- (u'jobs', u'carrier', u'more', u'left', u'trump', u'pasta')
# [(2.5566364909385593, 3), (0.91946483453176786, 1)] Trump’s Economic Cabinet Picks Signal Embrace of Wall St. Elite
# ------- (u'mnuchin', u'steven', u'treasury', u'trump\u2019s', u'president-elect', u'trump')
# ------- (u'trump', u'tuesday', u'donald', u'tower', u'president-elect', u'could')
# [(6.1797479172942005, 3), (1.8119067263920419, 4)] DealBook: Steven Mnuchin, Expected Treasury Pick, Is an Outsider to Public Policy
# ------- (u'mnuchin', u'steven', u'treasury', u'trump\u2019s', u'president-elect', u'trump')
# ------- (u'donald', u'trump', u'said', u'government', u'wednesday', u'president-elect')
# [(3.4256673335404075, 3), (1.0552020763684244, 4)] Breakingviews: Steven Mnuchin Is More Pragmatist Than Ideologue
# ------- (u'mnuchin', u'steven', u'treasury', u'trump\u2019s', u'president-elect', u'trump')
# ------- (u'donald', u'trump', u'said', u'government', u'wednesday', u'president-elect')
# [(5.5085893463698499, 1), (0.38899898877568828, 4)] Gary Cohn, a Potential Successor at Goldman, Could End Up With Trump
# ------- (u'trump', u'tuesday', u'donald', u'tower', u'president-elect', u'could')
# ------- (u'donald', u'trump', u'said', u'government', u'wednesday', u'president-elect')
# [(0.41901189470350109, 4), (0.0, 3)] OPEC Reaches Deal to Limit Production, Sending Prices Soaring
# ------- (u'donald', u'trump', u'said', u'government', u'wednesday', u'president-elect')
# ------- (u'mnuchin', u'steven', u'treasury', u'trump\u2019s', u'president-elect', u'trump')
# [(0.46597151774947781, 4), (1.9207016844295576e-18, 0)] Sheryl Sandberg Said to Plan $100 Million in Charitable Giving
# ------- (u'donald', u'trump', u'said', u'government', u'wednesday', u'president-elect')
# ------- (u'jobs', u'carrier', u'more', u'left', u'trump', u'pasta')
# [(6.766209868582628, 0), (0.36571589180943798, 1)] Trump Saved Jobs at Carrier, but More Midwest Jobs Are in Jeopardy
# ------- (u'jobs', u'carrier', u'more', u'left', u'trump', u'pasta')
# ------- (u'trump', u'tuesday', u'donald', u'tower', u'president-elect', u'could')
# [(6.6942809399923613, 4), (0.15486058316188675, 1)] Ethics Office Praises Donald Trump for a Move He Hasn’t Committed To
# ------- (u'donald', u'trump', u'said', u'government', u'wednesday', u'president-elect')
# ------- (u'trump', u'tuesday', u'donald', u'tower', u'president-elect', u'could')
# [(1.6617745552057175, 1), (8.3884233217301074e-05, 4)] Eyeing the Trump Voter, ‘Fight for $15’ Widens Its Focus
# ------- (u'trump', u'tuesday', u'donald', u'tower', u'president-elect', u'could')
# ------- (u'donald', u'trump', u'said', u'government', u'wednesday', u'president-elect')
# [(0.19122156471093571, 0), (8.1597739239997536e-14, 3)] Nestlé Reformulates Sugar and Says It Will Use Less in Its Candy
# ------- (u'jobs', u'carrier', u'more', u'left', u'trump', u'pasta')
# ------- (u'mnuchin', u'steven', u'treasury', u'trump\u2019s', u'president-elect', u'trump')
# [(0.41901189470350109, 4), (0.0, 3)] Lufthansa Joins Germany’s List of Companies in Distress
# ------- (u'donald', u'trump', u'said', u'government', u'wednesday', u'president-elect')
# ------- (u'mnuchin', u'steven', u'treasury', u'trump\u2019s', u'president-elect', u'trump')
# [(0.47007748111182257, 4), (0.0020228512807048183, 1)] ‘I Love N.Y.’ Signs Have a Lot to Say. The Government Says They’re Illegal.
# ------- (u'donald', u'trump', u'said', u'government', u'wednesday', u'president-elect')
# ------- (u'trump', u'tuesday', u'donald', u'tower', u'president-elect', u'could')
# [(0.070232126990840055, 4), (0.0028958259066601461, 0)] GoPro, the Action Camera Maker, Plans 200 Layoffs
# ------- (u'donald', u'trump', u'said', u'government', u'wednesday', u'president-elect')
# ------- (u'jobs', u'carrier', u'more', u'left', u'trump', u'pasta')
# [(0.49908102450195296, 4), (2.1666775840566082e-11, 0)] Britain’s New £5 Note, Stronger and Safer, Isn’t Suitable for Vegetarians
# ------- (u'donald', u'trump', u'said', u'government', u'wednesday', u'president-elect')
# ------- (u'jobs', u'carrier', u'more', u'left', u'trump', u'pasta')
# [(0.46597151774947781, 4), (1.9636253621070136e-18, 0)] Now, Netflix Users Can Watch Movies Offline on Their Mobile Devices
# ------- (u'donald', u'trump', u'said', u'government', u'wednesday', u'president-elect')
# ------- (u'jobs', u'carrier', u'more', u'left', u'trump', u'pasta')
# [(1.7670902299012834, 2), (2.2507729731416227e-37, 0)] China Manufacturing Heats Up in November, Inflation Pressure Builds
# ------- (u'coal', u'china', u'more', u'products', u'could', u'economic')
# ------- (u'jobs', u'carrier', u'more', u'left', u'trump', u'pasta')
# [(1.5894357481398029, 0), (0.26764615241242823, 4)] More Law Degrees for Women, but Fewer Good Jobs
# ------- (u'jobs', u'carrier', u'more', u'left', u'trump', u'pasta')
# ------- (u'donald', u'trump', u'said', u'government', u'wednesday', u'president-elect')
# [(0.60380364741158543, 4), (3.3460115636102872e-124, 3)] R.B.S. to Bolster Capital Position After Failing Stress Test
# ------- (u'donald', u'trump', u'said', u'government', u'wednesday', u'president-elect')
# ------- (u'mnuchin', u'steven', u'treasury', u'trump\u2019s', u'president-elect', u'trump')
# [(6.9058006897375552, 2), (3.1930211178148783e-06, 3)] Despite Climate Change Vow, China Pushes to Dig More Coal
# ------- (u'coal', u'china', u'more', u'products', u'could', u'economic')
# ------- (u'mnuchin', u'steven', u'treasury', u'trump\u2019s', u'president-elect', u'trump')
# [(4.074002386826173, 1), (0.60672647819498093, 4)] News Analysis: Why the Trump Team’s Economic Promises Will Be Hard to Execute
# ------- (u'trump', u'tuesday', u'donald', u'tower', u'president-elect', u'could')
# ------- (u'donald', u'trump', u'said', u'government', u'wednesday', u'president-elect')
# [(0.076212467207232654, 0), (0.0018786783081660382, 4)] State of the Art: While We Weren’t Looking, Snapchat Revolutionized Social Networks
# ------- (u'jobs', u'carrier', u'more', u'left', u'trump', u'pasta')
# ------- (u'donald', u'trump', u'said', u'government', u'wednesday', u'president-elect')
# [(0.086956590953600296, 3), (3.9364427475849721e-14, 1)] Trying Snap’s Spectacles: Live With the Look, Enjoy the View
# ------- (u'mnuchin', u'steven', u'treasury', u'trump\u2019s', u'president-elect', u'trump')
# ------- (u'trump', u'tuesday', u'donald', u'tower', u'president-elect', u'could')
# [(1.0783706786912473, 0), (2.0792442774191178e-07, 4)] How Banza, a Chickpea Pasta Start-Up, Thrives on Attention
# ------- (u'jobs', u'carrier', u'more', u'left', u'trump', u'pasta')
# ------- (u'donald', u'trump', u'said', u'government', u'wednesday', u'president-elect')
# [(4.8112765627330631, 4), (0.95495813232455828, 1)] Work-Life Balance: What Donald Trump Might Do for Working-Class Families
# ------- (u'donald', u'trump', u'said', u'government', u'wednesday', u'president-elect')
# ------- (u'trump', u'tuesday', u'donald', u'tower', u'president-elect', u'could')
# [(0.086956609348411457, 3), (3.9335571851410799e-14, 1)] Your Money Adviser: Recent College Grads Have Choices When Bills Start to Arrive
# ------- (u'mnuchin', u'steven', u'treasury', u'trump\u2019s', u'president-elect', u'trump')
# ------- (u'trump', u'tuesday', u'donald', u'tower', u'president-elect', u'could')
# [(2.8652121214595114, 1), (1.1946378366099113, 2)] Economic Scene: Earth Isn’t Doomed Yet. The Climate Could Survive Trump Policies.
# ------- (u'trump', u'tuesday', u'donald', u'tower', u'president-elect', u'could')
# ------- (u'coal', u'china', u'more', u'products', u'could', u'economic')
# [(0.020729129466060581, 0), (0.0, 4)] Michael James Delligatti, Creator of the Big Mac, Dies at 98
# ------- (u'jobs', u'carrier', u'more', u'left', u'trump', u'pasta')
# ------- (u'donald', u'trump', u'said', u'government', u'wednesday', u'president-elect')
# [(0.40032847750177708, 0), (9.2036210725645721e-38, 3)] Erich Bloch, Who Helped Develop IBM Mainframe, Dies at 91
# ------- (u'jobs', u'carrier', u'more', u'left', u'trump', u'pasta')
# ------- (u'mnuchin', u'steven', u'treasury', u'trump\u2019s', u'president-elect', u'trump')
# [(0.028873243987786908, 4), (0.028397172304639656, 0)] Grant Tinker, Former Chairman of NBC, Dies at 90; Made Network a Ratings Powerhouse
# ------- (u'donald', u'trump', u'said', u'government', u'wednesday', u'president-elect')
# ------- (u'jobs', u'carrier', u'more', u'left', u'trump', u'pasta')
# [(1.1212868065805528, 3), (0.54707835986024822, 1)] Mahmoud Abbas Proposes Palestinian Unity Government With Hamas
# ------- (u'president', u'south', u'father', u'after', u'korean', u'korea')
# ------- (u'cuba', u'president', u'havana', u'march', u'contributor', u'op-ed')
# [(7.5427771815261302, 2), (1.7757235238623485e-08, 0)] Let Women Drive, a Prince in Saudi Arabia Urges
# ------- (u'saudi', u'prince', u'time', u'plans', u'military', u'havana')
# ------- (u'fidel', u'castro', u'op-ed', u'contributor', u'time', u'havana')
# [(1.5754561848311861, 3), (0.019125969938645525, 1)] Colombia’s Congress Approves Peace Accord With FARC
# ------- (u'president', u'south', u'father', u'after', u'korean', u'korea')
# ------- (u'cuba', u'president', u'havana', u'march', u'contributor', u'op-ed')
# [(9.6682188192671433e-08, 4), (2.0301405451502125e-27, 3)] Doomed Jet Carrying Brazilian Team Reportedly Ran Out of Fuel
# ------- (u'national', u'movie', u'trump', u'north', u'korea', u'donald')
# ------- (u'president', u'south', u'father', u'after', u'korean', u'korea')
# [(0.52294730528375588, 3), (0.000984016938060242, 4)] As a Distracted Brazil Mourns, Lawmakers Gut a Corruption Bill
# ------- (u'president', u'south', u'father', u'after', u'korean', u'korea')
# ------- (u'national', u'movie', u'trump', u'north', u'korea', u'donald')
# [(2.9749720492340934, 4), (1.1768217818265385, 3)] U.N. Stiffens Sanctions on North Korea, Trying to Slow Its Nuclear March
# ------- (u'national', u'movie', u'trump', u'north', u'korea', u'donald')
# ------- (u'president', u'south', u'father', u'after', u'korean', u'korea')
# [(5.4215802455543338, 4), (1.3022140531226062e-20, 0)] Indian Cinemas Must Play the National Anthem, Supreme Court Rules
# ------- (u'national', u'movie', u'trump', u'north', u'korea', u'donald')
# ------- (u'fidel', u'castro', u'op-ed', u'contributor', u'time', u'havana')
# [(3.7414302170353659, 0), (0.32219990965315065, 2)] One Family. Six Decades. Myriad Views of Fidel Castro’s Revolution.
# ------- (u'fidel', u'castro', u'op-ed', u'contributor', u'time', u'havana')
# ------- (u'saudi', u'prince', u'time', u'plans', u'military', u'havana')
# [(4.7394871747123846, 1), (0.70205685054426614, 3)] Donald Trump’s Threat to Close Door Reopens Old Wounds in Cuba
# ------- (u'cuba', u'president', u'havana', u'march', u'contributor', u'op-ed')
# ------- (u'president', u'south', u'father', u'after', u'korean', u'korea')
# [(1.6568522807850594, 4), (1.2624246606197598, 1)] Subdued Cuba Prepares Memorial for Castro
# ------- (u'national', u'movie', u'trump', u'north', u'korea', u'donald')
# ------- (u'cuba', u'president', u'havana', u'march', u'contributor', u'op-ed')
# [(3.7641530304660606, 0), (0.37246864206502511, 1)] Op-Ed Contributor: The Little Fidel in All of Us
# ------- (u'fidel', u'castro', u'op-ed', u'contributor', u'time', u'havana')
# ------- (u'cuba', u'president', u'havana', u'march', u'contributor', u'op-ed')
# [(4.3117828383513555, 0), (2.3200404645774034e-06, 1)] Fidel Castro, Cuban Revolutionary Who Defied U.S., Dies at 90
# ------- (u'fidel', u'castro', u'op-ed', u'contributor', u'time', u'havana')
# ------- (u'cuba', u'president', u'havana', u'march', u'contributor', u'op-ed')
# [(0.17400115339339478, 3), (0.0, 4)] Lufthansa Joins Germany’s List of Companies in Distress
# ------- (u'president', u'south', u'father', u'after', u'korean', u'korea')
# ------- (u'national', u'movie', u'trump', u'north', u'korea', u'donald')
# [(0.036450486651194124, 3), (0.0, 4)] Charlie Hebdo, a Lightning Rod in France, Hits German Newsstands
# ------- (u'president', u'south', u'father', u'after', u'korean', u'korea')
# ------- (u'national', u'movie', u'trump', u'north', u'korea', u'donald')
# [(0.47824029102474297, 2), (0.39509307761836804, 3)] E.U. Plans Big Increase in Military Spending
# ------- (u'saudi', u'prince', u'time', u'plans', u'military', u'havana')
# ------- (u'president', u'south', u'father', u'after', u'korean', u'korea')
# [(0.83081856057497383, 3), (0.69358539596566993, 1)] Gambia’s Leader Vowed to Rule for a Billion Years. A Vote Will Test That.
# ------- (u'president', u'south', u'father', u'after', u'korean', u'korea')
# ------- (u'cuba', u'president', u'havana', u'march', u'contributor', u'op-ed')
# [(0.75494300934553915, 3), (4.5954746677813804e-61, 4)] Counterterrorism Law to Let Australia Detain Convicts After Their Sentences
# ------- (u'president', u'south', u'father', u'after', u'korean', u'korea')
# ------- (u'national', u'movie', u'trump', u'north', u'korea', u'donald')
# [(5.1027180467317521, 3), (0.11302539415216203, 4)] South Korean Arrested After Fire at Birthplace of President’s Father
# ------- (u'president', u'south', u'father', u'after', u'korean', u'korea')
# ------- (u'national', u'movie', u'trump', u'north', u'korea', u'donald')
# [(0.10110619116039822, 3), (0.0, 4)] Police Confiscate Passports in Parts of Xinjiang, in Western China
# ------- (u'president', u'south', u'father', u'after', u'korean', u'korea')
# ------- (u'national', u'movie', u'trump', u'north', u'korea', u'donald')
# [(0.061027694290644731, 2), (0.059202303745096697, 3)] Guggenheim Helsinki Museum Plans Are Rejected
# ------- (u'saudi', u'prince', u'time', u'plans', u'military', u'havana')
# ------- (u'president', u'south', u'father', u'after', u'korean', u'korea')
# [(1.7479835440256013, 3), (1.289226631802953, 1)] Jovenel Moïse Is Elected President of Haiti After Delays and Disasters
# ------- (u'president', u'south', u'father', u'after', u'korean', u'korea')
# ------- (u'cuba', u'president', u'havana', u'march', u'contributor', u'op-ed')
# [(0.45007737376302598, 3), (0.020999666022330107, 2)] Thailand’s Civil Servants Urged to Take a Break to Break a Sweat
# ------- (u'president', u'south', u'father', u'after', u'korean', u'korea')
# ------- (u'saudi', u'prince', u'time', u'plans', u'military', u'havana')
# [(1.1891153377840622, 3), (1.221015003621477e-33, 4)] Norcia Journal: Italian Monastery Seeks Salvation in Beer After Devastating Quake
# ------- (u'president', u'south', u'father', u'after', u'korean', u'korea')
# ------- (u'national', u'movie', u'trump', u'north', u'korea', u'donald')
# [(1.3788998327432735, 3), (0.55434355315371941, 4)] Bid to Impeach South Korean Leader Stalls as Lawmakers Debate Her Offer to Quit
# ------- (u'president', u'south', u'father', u'after', u'korean', u'korea')
# ------- (u'national', u'movie', u'trump', u'north', u'korea', u'donald')
# [(1.1444486089370944, 4), (0.49834876102934245, 1)] C.I.A. Chief Warns Donald Trump Against Tearing Up Iran Nuclear Deal
# ------- (u'national', u'movie', u'trump', u'north', u'korea', u'donald')
# ------- (u'cuba', u'president', u'havana', u'march', u'contributor', u'op-ed')
# [(5.9634854131836814, 4), (0.27442597899188903, 1)] Sinosphere: Michael Flynn, a Top Trump Adviser, Ties China and North Korea to Jihadists
# ------- (u'national', u'movie', u'trump', u'north', u'korea', u'donald')
# ------- (u'cuba', u'president', u'havana', u'march', u'contributor', u'op-ed')
# [(0.28435594157560784, 3), (6.7749333415801698e-217, 4)] Taking a Selfie in Berlin, With a 3-Ton Camera
# ------- (u'president', u'south', u'father', u'after', u'korean', u'korea')
# ------- (u'national', u'movie', u'trump', u'north', u'korea', u'donald')
# [(1.1444486089370933, 4), (0.49834876102934339, 1)] Editorial: A World of Trouble for Donald Trump
# ------- (u'national', u'movie', u'trump', u'north', u'korea', u'donald')
# ------- (u'cuba', u'president', u'havana', u'march', u'contributor', u'op-ed')
# [(4.1573267868496986, 1), (2.0295938131645315, 0)] Op-Ed Contributor: What Trump Misses About Cuba
# ------- (u'cuba', u'president', u'havana', u'march', u'contributor', u'op-ed')
# ------- (u'fidel', u'castro', u'op-ed', u'contributor', u'time', u'havana')
# [(4.3409838171581141, 1), (0.095137929308393598, 3)] Op-Ed Contributor: The Dream of a Free Cuba
# ------- (u'cuba', u'president', u'havana', u'march', u'contributor', u'op-ed')
# ------- (u'president', u'south', u'father', u'after', u'korean', u'korea')
# [(0.057193473134481157, 3), (7.566646653554954e-23, 4)] Where Even Nightmares Are Classified: Psychiatric Care at Guantánamo
# ------- (u'president', u'south', u'father', u'after', u'korean', u'korea')
# ------- (u'national', u'movie', u'trump', u'north', u'korea', u'donald')
# [(0.057193473134481157, 3), (1.2814208303880756e-22, 4)] Turkish Dam Project Threatens to Submerge Thousands of Years of History
# ------- (u'president', u'south', u'father', u'after', u'korean', u'korea')
# ------- (u'national', u'movie', u'trump', u'north', u'korea', u'donald')

# %% [markdown]
# ## Aufgaben
#
# 1. Analysieren Sie die berechneten Topics indem Sie sich überlegen ob die gefundenen 6 Wörter pro Topic wirklich Themen beschreiben.
# 2. Verändern Sie die Parameter der NNMF (Anzahl der Topics $m$, Anzahl der Iterationen). Bei welcher Einstellung der Parameter erhalten Sie das für sie sinnvollste Resultat (sinnvolle Topics)?
# 3. Wie kann die _getwords()_ Methode verbessert werden, so dass noch bedeutsamere Topics gefunden werden?

# %% [markdown]
# ### Aufgabe 1
# Ein Teil der gefundenen Wörter für die Topics sind Aussagekräftig, viele Topics behalten allerdings auch Zeichen oder nichtssagende Abkürzungen.z
#
#
# ### Aufgabe 3
# Um Abkürzungen zu vermeiden, wie z.B 'mr.' oder 'j.' zu vermeiden sollte der String nicht nur einfach gesplittet werden, sondern es sollte ein Tokenizer verwendet werden, der Zusammengehörige Wörter als ein Wort behandelt. Desweiteren sollten bestimmte Sonderzeichen entfernt werden.
